# %% [markdown]
# # Goals:
# - (convert) simulate left arrow until end with delay
# - (custom ocr) image to text
# - (tokenizer) text to words
# - (anki-tool) words to anki
#
#
#
# Rules for this notebook:
# - imports all at top,
# - make everything into functions
# - modularize and streamline

# %%
# %pip install pyautogui
# %pip install PyGetWindow
# %pip install keyboard
# %pip install PyQt5 --user
# %pip install win32gui

# %%
import functools
import json

import os
import re
import subprocess
import sys
import time
import urllib.request
from collections import defaultdict
from datetime import (
    date,
    datetime,
    timedelta
)
from pathlib import Path

import keyboard
import MeCab
import pyautogui
import pygetwindow
import win32gui
from jisho_api.word import Word
from PIL import Image, ImageGrab

# %% [markdown]
# # (automation)
# - find kindle window
# - take screenshot
# - left arrow, wait, repeat

# %%
# Page Turner and Screen Capture
def page_turner(seconds, output_dir):

    # This Kindle Window part was ChatGPT assisted
    print("Focusing on Kindle window")
    kindle_window = None
    for window in pygetwindow.getAllTitles():
        if "Kindle" in window:
            kindle_window = pygetwindow.getWindowsWithTitle(window)[0]
            kindle_window.activate()
            break
    if not kindle_window:
        print("Kindle is not open. Ending")
        return 

    print("page_turner starting in 3 seconds...")
    time.sleep(3)
    if not os.path.exists(output_dir):
        print(f"Output dir does not exist: {output_dir}")
        return
    for t in range(seconds):
        timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
        sc: Image = pyautogui.screenshot(f'{output_dir}/{timestamp}_{t}.png')
        pyautogui.press('left')
        time.sleep(1)

# %%
# It worked!! -> did on 
# -> K Evan's Kindle for PC -GA文庫 & GAノベル 2018年5月の新刊 全作品立読み(合本版) (GA文庫) (Japanese Edition)
# page_turner(60, "full-book-notes-img")

# %% [markdown]
# # (ocr)
# - take img dir
# - run each img through ocr script
# - save each txt to another dir

# %%
def run_ocr(input_file = "file/img.jpg", output_file = "file/imgjpg.txt"):
    custom_ocr_path = "/nav/gith/jp-card-gen/custom-ocr/src/"
    cmd = f'cd {custom_ocr_path} && python -u main.py -m main -i "{input_file}" -o "{output_file}" && echo "Done" '

    """
    Below Part Generated by ChatGPT
    """
    try:
        # Run the command
        process = subprocess.run(
            cmd,
            shell=True,                # Use shell=True to execute the command in a shell
            stdout=subprocess.PIPE,    # Capture standard output
            stderr=subprocess.PIPE,    # Capture standard error
            text=True                  # Decode output to strings
        )

        # Wait for the process to complete
        # subprocess.run does this automatically

        # Access the output
        stdout = process.stdout
        stderr = process.stderr
        return_code = process.returncode

        # print(f"Standard Output:\n{stdout}")
        # print(f"Standard Error:\n{stderr}")
        # print(f"Return Code: {return_code}")
        print(f"RC: {return_code}, for {input_file}, {output_file}")

    except Exception:
        print("An error occurred: ")

# %%
def convert_book_to_txt(image_dir, text_dir):
    if not os.path.exists(image_dir):
        print(f"Image directory does not exist: {image_dir}")
        return 

    # Gather files
    directory = Path(image_dir)
    # maybe could simplify this?
    files = sorted(file.name for file in directory.iterdir() if file.is_file())
    ios = []
    for file in files:
        # print(file)
        # if "png" in file:
        file_base_name = file.split(".")[0]
        ios.append((image_dir+file, text_dir+file_base_name+".txt"))
    print(len(ios))
    if not os.path.exists(text_dir):
        os.mkdir(text_dir)

    for i, o in ios:
        # print(i, o)
        run_ocr(input_file=i, output_file=o)

# %%
dir_base_name = "full-book-notes"
full_path = f"/nav/gith/jp-card-gen/{dir_base_name}"
# r = range(0, 5)
# r = range(5, 60)

# This worked!!!
# convert_book_to_txt(image_dir=full_path+"-img/", text_dir=full_path+"-text/")

# %% [markdown]
# # (separate)
# - loop over all text files
# - (take from jp-lang-tokenizers.ipynb) mecab each file
# -

# %%
dictdir = "c:\\Python312\\Lib\\site-packages\\unidic_lite\\dicdir"

# %%
def clean(words):
    """Remove spaces, and all punctuation"""
    new_hl = []
    punc = ''' !()-[]{};:'"\\,<>./?@#$^&*_~「」（）・＿。｛｝；：！
    『』【】…？,、－、〟
    '''
    # also remove numbers
    numbers = "1234567890１２３４５６７８９０"
    for hl in words:
        for c in hl:
            if c in punc:
                hl = hl.replace(c, "")
            elif c in numbers:
                hl = hl.replace(c, "")

        if hl != '':
            new_hl.append(hl)
    return new_hl

def exclude_kana_only_words(word_list):
    """
    GENERATED BY CHATGPT
    Exclude words that consist only of Hiragana, Katakana, or related symbols.
    
    Args:
    - word_list (list of str): A list of words to filter.
    
    Returns:
    - list of str: Words that are not exclusively Kana.
    """
    # Regular expression for Hiragana, Katakana, and associated symbols
    kana_pattern = re.compile(r'^[\u3040-\u309F\u30A0-\u30FFーぁィっa-zA-Z]+$')
    
    # Filter out Kana-only words
    return [word for word in word_list if not kana_pattern.fullmatch(word)]

# %%
def create_list(text, no_print=False):
    # tagger = MeCab.Tagger() # change where the mecabrc / dictdir is...
    tagger = MeCab.Tagger(f'-r "{dictdir+"\\mecabrc"}" -d "{dictdir}"')
    tag_parsed = set()
    for line in tagger.parse(text).splitlines():
        ls = line.split()
        if not no_print:
            print(len(ls), ls)
        word = None
        for item in reversed(ls):
            if "動詞" in item:
                word = ls[3]
                break
                # ls[3] is dict form for verbs
            if "形容詞" in item:
                word = ls[3]
                # ls[3] is dict form for adjs
            if "名詞" in item:
                word = ls[0]
                break
        if word==None:
            word = ls[0]
        tag_parsed.add(word)
    return tag_parsed

# %%
# TODO LATER: sort by kana...
def text_parse_clean(text_dir) -> (set[str], list[str]): 
    """Create word list from text file"""
    # Modified to take a list intead of single
    if not os.path.exists(text_dir):
        print(f"Image directory does not exist: {text_dir}")
        return 

    # Gather files
    directory = Path(text_dir)
    fpaths = sorted(file for file in directory.iterdir() if file.is_file())

    all_text = set()
    all_results = []
    all_raw: int = 0
    all_cleaned: int = 0


    for fpath in fpaths:
        with open(fpath, 'r', encoding='utf-8') as file:
            text = file.read()
        text_parsed = create_list(text, no_print=True)
        text_cleaned = clean(text_parsed)
        text_kanaless = exclude_kana_only_words(text_cleaned)
        # print(sorted(text_kanaless))
        
        results = f"{len(text_parsed)} -> {len(text_cleaned)} -> {len(text_kanaless)} -> {fpath}"
        print(results)

        all_raw += len(text_parsed)
        all_cleaned += len(text_cleaned)
        all_results.append(results)

        for word in text_kanaless:
            all_text.add(word)

    total = f"Files: {len(fpaths)} ---> Raw: {all_raw} ---> Cleaned: {all_cleaned} ---> Total: {len(all_text)}"
    print(total)
    all_results.append(total)
    return all_text, all_results

# %%
def write_file(FPATH, word_list):
    with open(FPATH, 'w', encoding='utf-8') as file:
        for item in word_list:
            file.write(f"{item}\n")

# %%
OLD_FILE_DIR = "full-book-notes-text"
NEW_FILE_PATH = "full-book-notes-results/parsed.txt"
LOG_FILE_PATH = "full-book-notes-results/parsed.log"

# %%
full_list, results = text_parse_clean(OLD_FILE_DIR)
write_file(NEW_FILE_PATH, full_list)
write_file(LOG_FILE_PATH, results)
# Out:
# 358 -> 336 -> 205 -> full-book-notes-text\2024-12-08T20-15-15_0.txt
# 371 -> 345 -> 214 -> full-book-notes-text\2024-12-08T20-15-16_1.txt
# 443 -> 417 -> 250 -> full-book-notes-text\2024-12-08T20-15-17_2.txt
# 351 -> 322 -> 170 -> full-book-notes-text\2024-12-08T20-15-19_3.txt
# 294 -> 268 -> 149 -> full-book-notes-text\2024-12-08T20-15-20_4.txt
# 64 -> 43 -> 7 -> full-book-notes-text\2024-12-08T20-15-21_5.txt
# 370 -> 345 -> 207 -> full-book-notes-text\2024-12-08T20-15-23_6.txt
# 375 -> 351 -> 222 -> full-book-notes-text\2024-12-08T20-15-24_7.txt
# 119 -> 93 -> 34 -> full-book-notes-text\2024-12-08T20-15-25_8.txt
# 72 -> 50 -> 11 -> full-book-notes-text\2024-12-08T20-15-27_9.txt
# 116 -> 93 -> 34 -> full-book-notes-text\2024-12-08T20-15-28_10.txt
# 136 -> 105 -> 58 -> full-book-notes-text\2024-12-08T20-15-29_11.txt
# 106 -> 86 -> 24 -> full-book-notes-text\2024-12-08T20-15-30_12.txt
# 64 -> 42 -> 6 -> full-book-notes-text\2024-12-08T20-15-32_13.txt
# 97 -> 78 -> 24 -> full-book-notes-text\2024-12-08T20-15-33_14.txt
# 104 -> 84 -> 34 -> full-book-notes-text\2024-12-08T20-15-35_15.txt
# 83 -> 64 -> 19 -> full-book-notes-text\2024-12-08T20-15-36_16.txt
# 99 -> 79 -> 28 -> full-book-notes-text\2024-12-08T20-15-38_17.txt
# 111 -> 90 -> 39 -> full-book-notes-text\2024-12-08T20-15-39_18.txt
# 67 -> 45 -> 7 -> full-book-notes-text\2024-12-08T20-15-41_19.txt
# 97 -> 76 -> 28 -> full-book-notes-text\2024-12-08T20-15-42_20.txt
# 78 -> 55 -> 13 -> full-book-notes-text\2024-12-08T20-15-44_21.txt
# 123 -> 101 -> 46 -> full-book-notes-text\2024-12-08T20-15-45_22.txt
# 70 -> 48 -> 9 -> full-book-notes-text\2024-12-08T20-15-46_23.txt
# 106 -> 86 -> 45 -> full-book-notes-text\2024-12-08T20-15-47_24.txt
# 318 -> 292 -> 166 -> full-book-notes-text\2024-12-08T20-15-49_25.txt
# 282 -> 254 -> 143 -> full-book-notes-text\2024-12-08T20-15-50_26.txt
# 302 -> 277 -> 144 -> full-book-notes-text\2024-12-08T20-15-51_27.txt
# 248 -> 222 -> 107 -> full-book-notes-text\2024-12-08T20-15-53_28.txt
# 331 -> 304 -> 168 -> full-book-notes-text\2024-12-08T20-15-54_29.txt
# 299 -> 274 -> 150 -> full-book-notes-text\2024-12-08T20-15-55_30.txt
# 279 -> 254 -> 134 -> full-book-notes-text\2024-12-08T20-15-57_31.txt
# 317 -> 292 -> 159 -> full-book-notes-text\2024-12-08T20-15-58_32.txt
# 248 -> 223 -> 123 -> full-book-notes-text\2024-12-08T20-15-59_33.txt
# 64 -> 42 -> 6 -> full-book-notes-text\2024-12-08T20-16-00_34.txt
# 312 -> 286 -> 153 -> full-book-notes-text\2024-12-08T20-16-02_35.txt
# 312 -> 286 -> 150 -> full-book-notes-text\2024-12-08T20-16-03_36.txt
# 246 -> 219 -> 108 -> full-book-notes-text\2024-12-08T20-16-05_37.txt
# 65 -> 43 -> 7 -> full-book-notes-text\2024-12-08T20-16-06_38.txt
# 311 -> 286 -> 146 -> full-book-notes-text\2024-12-08T20-16-07_39.txt
# 306 -> 278 -> 149 -> full-book-notes-text\2024-12-08T20-16-09_40.txt
# 146 -> 123 -> 49 -> full-book-notes-text\2024-12-08T20-16-10_41.txt
# 72 -> 50 -> 11 -> full-book-notes-text\2024-12-08T20-16-11_42.txt
# 119 -> 95 -> 35 -> full-book-notes-text\2024-12-08T20-16-12_43.txt
# 125 -> 93 -> 47 -> full-book-notes-text\2024-12-08T20-16-14_44.txt
# 92 -> 72 -> 27 -> full-book-notes-text\2024-12-08T20-16-15_45.txt
# 64 -> 42 -> 6 -> full-book-notes-text\2024-12-08T20-16-16_46.txt
# 90 -> 70 -> 30 -> full-book-notes-text\2024-12-08T20-16-18_47.txt
# 82 -> 63 -> 18 -> full-book-notes-text\2024-12-08T20-16-19_48.txt
# 79 -> 61 -> 22 -> full-book-notes-text\2024-12-08T20-16-21_49.txt
# 81 -> 63 -> 19 -> full-book-notes-text\2024-12-08T20-16-22_50.txt
# 80 -> 61 -> 21 -> full-book-notes-text\2024-12-08T20-16-23_51.txt
# 92 -> 71 -> 29 -> full-book-notes-text\2024-12-08T20-16-25_52.txt
# 66 -> 44 -> 8 -> full-book-notes-text\2024-12-08T20-16-26_53.txt
# 90 -> 70 -> 28 -> full-book-notes-text\2024-12-08T20-16-28_54.txt
# 123 -> 101 -> 46 -> full-book-notes-text\2024-12-08T20-16-29_55.txt
# 68 -> 46 -> 9 -> full-book-notes-text\2024-12-08T20-16-30_56.txt
# 85 -> 66 -> 28 -> full-book-notes-text\2024-12-08T20-16-32_57.txt
# 243 -> 214 -> 102 -> full-book-notes-text\2024-12-08T20-16-33_58.txt
# 232 -> 204 -> 105 -> full-book-notes-text\2024-12-08T20-16-34_59.txt
# Files: 60 ---> Raw: 10543 ---> Cleaned: 9143 ---> Total: 1874

# %% [markdown]
# # (comparator)
# - (shorten anki-tool.ipynb) anki comparator tool

# %%
def request(action, **params):
    return {'action': action, 'params': params, 'version': 6}

def invoke(action, debug=False, **params):
    requestJson = json.dumps(request(action, **params)).encode('utf-8')
    if debug: 
        print(requestJson)
    response = json.load(urllib.request.urlopen(urllib.request.Request('http://localhost:8765', requestJson)))
    if debug: 
        print(response)
    if len(response) != 2:
        raise Exception('response has an unexpected number of fields')
    if 'error' not in response:
        raise Exception('response is missing required error field')
    if 'result' not in response:
        raise Exception('response is missing required result field')
    if response['error'] is not None:
        raise Exception(response['error'])
    return response['result']

# %%
# https://stackoverflow.com/questions/33338713/filtering-out-all-non-kanji-characters-in-a-text-with-python-3
# filter out others...

def is_not_hiragana_or_katakana(char):
    """
    Check if a character is not hiragana or katakana
    *from ChatGPT

    # Example usage
    characters = "あいうえおアイウエオ漢字"
    filtered_characters = [char for char in characters if is_not_hiragana_or_katakana(char)]

    print("Original Characters:", characters)
    print("Filtered Characters:", "".join(filtered_characters))
    """
    import re
    # Define regular expressions for Hiragana and Katakana
    hiragana_pattern = re.compile(r'[\u3041-\u3096ー]')  # Hiragana
    katakana_pattern = re.compile(r'[\u30A0-\u30FFー]')  # Katakana

    # Check if the character is not a Hiragana or Katakana character
    return not (hiragana_pattern.match(char) or katakana_pattern.match(char))

# %%
def get_kanji(word_list):
    # from gpt
    with open(word_list, encoding='utf-8') as f:
        lines = [line.rstrip('\n') for line in f.readlines()]

    # set
    kanji_to_search = set()
    for line in lines:
        for char in line:
            # TODO (ebui): filter out all non kanji characters
            if is_not_hiragana_or_katakana(char):
                kanji_to_search.add(char)

    # Get Entire Deck (findCards -> cardsInfo) 7s
    query = "deck:nhg::1kanji"
    search_result = invoke("findCards", query=query)
    card_info = invoke("cardsInfo", cards=search_result)

    # Create Map
    cards = dict()
    failed = list()
    for card in card_info:
        try:
            kanji = card["fields"]["Kanji"]["value"]
            cards[kanji] = card["interval"]
        except KeyError as ke:
            failed.append(card)


    # Search
    to_learn = set()
    learned = set()
    not_found = set()
    for kanji in kanji_to_search:
        try:
            if cards[kanji] == 0:
                to_learn.add(kanji)
            elif cards[kanji] > 0:
                learned.add(kanji)
        except Exception:
            not_found.add(kanji)

    print("--")
    print("To learn:\t", len(to_learn), to_learn)
    print("Learned:\t", len(learned), learned)
    print("Not Found:\t", len(not_found), not_found)

    return to_learn, learned

# %%
def get_words(word_list):
    # from gpt
    with open(word_list, encoding='utf-8') as f:
        lines = [line.rstrip('\n') for line in f.readlines()]

    # set
    words_to_search = set(lines)

    # Get Entire Deck (findCards -> cardsInfo) 7s
    query = "deck:nhg::3vocab"
    search_result = invoke("findCards", query=query)
    card_info = invoke("cardsInfo", cards=search_result)

    # Create Map
    cards = dict()
    failed = list()

    to_skip = set()
    for card in card_info:
        try:
            vocab = card["fields"]["Word"]["value"]
            if card["deckName"] == SKIP_DECK:
                # to_skip.add(vocab)
                cards[vocab] = -100000
            else:
                cards[vocab] = card["interval"]
        except KeyError as ke:
            failed.append(card)

    # Info
    to_learn = set()
    learned = set()
    not_found = set()
    for word in words_to_search:
        try:
            if cards[word] == 0:
                to_learn.add(word)
            elif cards[word] > 0:
                learned.add(word)
            elif cards[word] == -100000:
                to_skip.add(word)
        except Exception:
            not_found.add(word)

    print("--")
    print("to learn:\t", len(to_learn), to_learn)
    print("learned:\t", len(learned), learned)
    print("to add:\t", len(not_found), not_found)
    print("to skip:\t", len(to_skip), to_skip)
    print("failed:\t",  len(failed), failed)
    # return to_learn.union(not_found), learned, to_skip, failed
    return to_learn.union(not_found), learned, to_skip

# %%
def analyze_list(word_list):
    kanji_unlearned, kanji_learned = get_kanji(word_list)
    words_unlearned, words_learned, to_skip = get_words(word_list)

    # word true/false, kanji true/false
    wf_kt = set() # Easy Words
    wf_kf = set() # Low Prio Words
    wt_kf = set() # High Prio Kanji
    wt_kt = set() # Known


    for word in words_unlearned:
        known = True
        for char in word:
            if char in kanji_unlearned:
                wf_kf.add(word)
                known = False
                break
        if known:
            wf_kt.add(word)
    for word in words_learned:
        known = True
        for char in word:
            if char in kanji_unlearned:
                wt_kf.add(word)
                known = False
                break
        if known:
            wt_kt.add(word)

    # Warning: ignores words with kanji not found, doesn't separate words not found
    print("--")
    print("wf_kt,\tEasy Words:", len(wf_kt), sorted(wf_kt, key=len))
    print("wf_kf,\tLow Prio Word:", len(wf_kf), wf_kf)
    print("wt_kf,\tHigh Prio Kanji:", len(wt_kf), wt_kf)
    print("wt_kt,\tKnown Words:", len(wt_kt), sorted(wt_kt, key=len))
    print("UNNEEDED (SKIP): \t", len(to_skip), sorted(to_skip, key=len))
    print()
    # easy, low, kanji, known
    return  sorted(wf_kt, key=len), sorted(wf_kf, key=len)

# %%
SKIP_DECK = "nhg::3vocab::unneeded"
FILE_NAME = "full-book-notes-results/parsed.txt"
easy, low = analyze_list(FILE_NAME)

# THESE ANALYSIS RESULTS NEED TO BE LOGGED in addition to the printing
# Out:
# --
# To learn:	 27 {'遥', '焉', '訝', '漉', '絨', '楕', '畏', '燻', '堵', '鱗', '猪', '閑', '漆', '憐', '沃', '冨', '淳', '牽', '翠', '於', '媚', '弥', '芳', '某', '恭', '呉', '瞑'}
# Learned:	 1068 {'崩', '型', '補', '皮', '廊', '論', '飾', '徴', '要', '略', '刊', '輝', '遂', '転', '憶', '死', '予', '息', '自', '学', '伐', '鉱', '痴', '伸', '敷', '題', '肉', '規', '南', '認', '必', '乱', '称', '客', '召', '元', '像', '是', '刷', '距', '準', '丸', '週', '雷', '才', '復', '籠', '特', '介', '闘', '掻', '尾', '運', '土', '減', '積', '友', '料', '針', '暗', '表', '恐', '弱', '組', '口', '示', '粗', '旨', '費', '触', '配', '研', '理', '大', '正', '重', '魔', '巣', '兄', '制', '豹', '読', '夜', '火', '実', '塊', '択', '戸', '性', '咲', '練', '負', '部', '根', '華', '頂', '駐', '会', '直', '戦', '賑', '豆', '紹', '黒', '経', '語', '馬', '玉', '偉', '夢', '価', '務', '奪', '何', '青', '吐', '浮', '軽', '悔', '迫', '裕', '剣', '念', '響', '主', '膝', '他', '鼻', '記', '堂', '徹', '黄', '了', '員', '文', '去', '章', '財', '傾', '前', '刃', '飲', '羽', '審', '竹', '績', '喧', '番', '光', '沈', '晴', '隣', '柄', '精', '枚', '限', '件', '羊', '立', '草', '画', '駄', '熟', '足', '彼', '異', '右', '努', '筋', '義', '詠', '団', '殺', '怪', '振', '杖', '街', '父', '愚', '唱', '楽', '効', '宮', '生', '株', '早', '添', '監', '具', '心', '甘', '朝', '冷', '血', '拒', '吸', '見', '助', '残', '険', '痛', '雪', '赤', '回', '机', '笑', '当', '整', '入', '収', '障', '開', '普', '災', '既', '結', '髪', '遣', '昔', '舞', '索', '住', '集', '貧', '考', '目', '現', '三', '果', '恵', '力', '底', '皆', '后', '権', '祝', '欲', '呪', '覗', '観', '反', '締', '撤', '麗', '腰', '医', '臨', '差', '告', '防', '冬', '曲', '本', '勝', '割', '常', '怖', '労', '玄', '動', '騙', '除', '酒', '分', '地', '顔', '床', '殿', '容', '写', '伝', '紺', '勘', '興', '呼', '級', '姿', '吹', '者', '耳', '対', '装', '健', '止', '太', '越', '再', '首', '満', '違', '無', '鍛', '趣', '勢', '末', '督', '毎', '倒', '期', '順', '豪', '問', '厚', '挑', '乏', '想', '戻', '廷', '謝', '酔', '摂', '叫', '移', '存', '深', '伏', '堪', '紙', '売', '嬢', '闇', '鋭', '完', '成', '醜', '案', '佐', '冒', '荷', '作', '男', '以', '縄', '俺', '洗', '散', '嘆', '簡', '襟', '逆', '方', '教', '須', '親', '半', '向', '詰', '役', '登', '込', '片', '怒', '濃', '短', '倍', '服', '依', '脈', '民', '巨', '水', '答', '歩', '鼓', '掌', '基', '緑', '随', '嘘', '君', '階', '非', '八', '眉', '素', '纏', '進', '音', '平', '蔑', '近', '応', '慨', '室', '描', '書', '信', '専', '達', '王', '拍', '呆', '悠', '扱', '空', '撃', '源', '休', '培', '妄', '鹿', '架', '握', '誰', '館', '任', '由', '次', '将', '印', '齢', '況', '討', '賢', '言', '屋', '打', '扉', '飛', '納', '一', '透', '揺', '多', '座', '思', '機', '肥', '着', '諦', '質', '聖', '際', '付', '湖', '擦', '品', '施', '柱', '栄', '控', '童', '囲', '身', '業', '似', '恥', '国', '冗', '値', '候', '縁', '五', '来', '兼', '共', '窟', '欄', '織', '事', '求', '証', '庭', '惑', '即', '礫', '柔', '侮', '幸', '忙', '西', '査', '酬', '士', '獣', '替', '暁', '誉', '編', '秀', '議', '角', '僅', '量', '美', '選', '真', '就', '頬', '沸', '覚', '否', '巻', '端', '胸', '探', '迷', '円', '得', '憎', '第', '腐', '両', '産', '緩', '間', '字', '超', '燃', '発', '午', '採', '獲', '離', '賭', '京', '陸', '適', '遠', '悲', '覇', '仮', '便', '複', '千', '械', '識', '遅', '天', '情', '豊', '約', '掴', '協', '畜', '授', '奮', '眺', '紋', '給', '詫', '逃', '界', '初', '景', '買', '総', '鬼', '喫', '新', '治', '霊', '味', '返', '後', '線', '派', '子', '係', '旅', '珍', '日', '徳', '留', '広', '女', '区', '絶', '羨', '待', '老', '所', '奥', '唾', '用', '資', '磨', '占', '領', '轟', '下', '互', '中', '師', '安', '政', '渡', '病', '降', '東', '判', '迎', '諸', '調', '送', '処', '落', '褒', '奴', '裁', '武', '年', '継', '括', '談', '製', '契', '院', '測', '砕', '川', '今', '相', '内', '気', '雲', '固', '接', '急', '惜', '狂', '官', '辿', '詳', '策', '名', '陛', '礼', '活', '始', '感', '炎', '横', '挨', '話', '署', '築', '拘', '陰', '康', '揃', '厳', '乗', '害', '躍', '外', '格', '器', '属', '薬', '場', '頑', '優', '謀', '眼', '折', '喜', '我', '兵', '群', '愛', '私', '溢', '貰', '難', '腕', '幼', '諾', '庫', '赦', '鉄', '壁', '裂', '確', '先', '皇', '偵', '含', '希', '電', '翻', '有', '承', '切', '色', '暮', '瞳', '誕', '造', '盛', '節', '然', '寧', '突', '芸', '驚', '黙', '個', '額', '合', '喚', '構', '忘', '術', '染', '族', '奇', '掛', '層', '追', '蓄', '報', '侵', '仰', '丁', '椅', '臣', '放', '導', '度', '試', '意', '済', '建', '働', '標', '瞼', '哀', '威', '数', '貴', '漏', '延', '育', '交', '最', '張', '都', '頃', '嫌', '敵', '挟', '押', '雇', '絵', '譲', '駆', '食', '抜', '十', '混', '宝', '貸', '史', '決', '式', '説', '道', '帝', '担', '頭', '球', '著', '煩', '指', '敗', '掲', '察', '噛', '通', '六', '備', '々', '御', '閉', '絡', '訓', '仕', '茶', '人', '更', '木', '加', '噂', '据', '隷', '葉', '遊', '肩', '野', '北', '従', '骨', '象', '世', '変', '零', ...
# Not Found:	 31 {'◇', '%', '呻', '撥', '€', '०', '靡', '滾', '〜', '©', '―', 'ㄈ', '☐', '←', 'ㄖ', '毯', '☑', '强', '翡', '×', '詬', '✓', '+', '१', 'Ő', '=', 'ㄨ', '･', '୪', '·', '◆'}
# --
# to learn:	 180 {'関', '芳しい', '通路', '言い切る', '一心', '分け前', '行き来', '次期', '金貨', '実体', '素質', '押し込む', '粗野', '一定', '停滞', '脱退', '大使', '伸', '契機', '病状', '軽々', '歴代', '筋力', '足取り', '交差', '醜悪', '近々', '言葉遣い', '不毛', '表わす', '書類', '軍部', '実地', '峰', '判', '随一', '荒らす', '商業', '差し出す', '砕ける', '持ち', '濃紺', '意地', '適性', '悔やむ', '新規', '名目', '国政', '満喫', '起き上がる', '為さる', '一流', '本国', '筆頭', '傾げる', '解体', '小川', '全土', '駐在', '軽やか', '聞き返す', '政務', '苦い', '向こう側', '負', '口数', '国体', '向き', '調達', '言い分', '漆黒', '大国', '付与', '辿り着く', '当分', '立ち読み', '先端', '聞き取る', '一角', '文面', '奇異', '気質', '接近', '素', '入り込む', '洗練', '間近', '裁定', '目下', '山脈', '宝玉', '一層', '称号', '書簡', '取り掛かる', '靡く', '取り残す', '突く', '直撃', '館', '相応しい', '体質', '代', '来客', '盛ん', '信ずる', '一室', '侵攻', '柔らか', '発する', '来訪', '半ば', '座', '達人', '装飾', '身なり', '意気', '対処', '五十', '襟元', '存ずる', '静脈', '運び', '視界', '中庭', '開花', '真似', '占領', '君主', '人目', '主従', '東方', '聖堂', '建国', '資質', '終焉', '背骨', '口調', '集う', '旅人', '開放', '請け負う', '鉄板', '驚異', '浮かび上がる', '言及', '立地', '大物', '置き去り', '内政', '個室', '駐留', '決戦', '差し掛かる', '有無', '体裁', '亡者', '要人', '薬草', '名物', '張り出す', '強気', '相当', '物陰', '暴走', '穿つ', '鼻息', '眼差し', '引き渡す', '交易', '水晶', '反る', '動脈', '飛び込む', '顔立ち', '清々しい', '回廊', '見付ける', '手配', '強固'}
# learned:	 1251 {'平常', '上げる', '同じ', '健康', '息', '乗り越える', '身分', '元', '押す', '人生', '申し訳', '口', '代金', '東部', '大', '属性', '実', '性', '最高', '風景', '本格', '抱える', '処置', '入る', '何', '青', '相手', '膝', '他', '堂', '表情', '凄い', '政治', '生きる', '番', '光', '送る', '件', '体力', '詠唱', '玄関', '成立', '難易', '仕方', '成る', '感情', '幸い', '執筆', '許諾', '順番', '羨ましい', '行く', '新刊', '血', '下げる', '動く', '最低', '将来', '背景', '動作', '規模', '仕草', '企業', '利用', '三', '力', '生活', '感じ', '移動', '掛かる', '精霊', '冬', '一筋', '予想', '床', '重量', '即座', '勘', '廊下', '支払う', '大変', '案外', '近い', '無', '飛び出す', '午後', '調べる', '甘える', '赤字', '逆', '方', '反発', '割合', '荒い', '訓練', '病院', '民', '示す', '乗る', '互い', '一大', '不審', '王子', '運動', '王', '押さえる', '関わる', '籠もる', '装備', '愚痴', '土地', '勝つ', '一', '直後', '報告', '湖', '気分', '心配', '柱', '騙す', '類い', '西', '越える', '死ぬ', '妨害', '一員', '隣国', '現状', '投げる', '結構', '毎年', '従う', '真剣', '生まれる', '笑う', '国内', '王女', '退屈', '満足', '変化', '内外', '落ち着く', '済む', '新', '報酬', '頷く', '後', '係', '画面', '世の中', '話す', '傍ら', '噛む', '疑う', '期待', '東', '着る', '解ける', '雲', '名', '横', '出世', '作る', '必ず', '授与', '腕', '通用', '陛下', '寄越す', '基本', '産業', '芸', '雰囲気', '求める', '異なる', '呆然', '行う', '自体', '零す', '透き通る', '気配', '安全', '年間', '口絵', '身体', '通る', '思う', '重厚', '情報', '輝き', '日本', '決意', '球', '大型', '六', '皇帝', '急ぐ', '人', '噂', '緊張', '立ち上がる', '思想', '誕生', '優先', '遊ぶ', '変', '練る', '浮かぶ', '見事', '貧乏', '日常', '足りる', '一方', '譲る', '懸念', '山', '間違える', '豊か', '少々', '取る', '好く', '妄想', '体', '支える', '臨時', '協力', '時間', '途端', '辛い', '会話', '掲示', '無理', '貴重', '袖', '大半', '版', '時', '規格', '易い', '背', '兵隊', '終わる', '挟む', '初代', '等', '絡む', '減る', '削る', '笑顔', '広い', '至る', '少ない', '見なす', '近く', '不足', '振る', '許可', '対応', '就職', '聞く', '請求', '閉じる', '恐らく', '四', '馬鹿', '舎', '声', '経過', '認める', '殺す', '歴史', '個人', '関節', '採取', '忘れる', '花', '嵐', '軍', '余裕', '元々', '慌てる', '想定', '争う', '詰まる', '適正', '返答', '更新', '手', '頂く', '仕立て', '株式', '楽しむ', '収まる', '結論', '意見', '初心', '厄介', '掻く', '席', '引き継ぐ', '向かう', '浮かべる', '買う', '遠方', '起きる', '動かす', '組織', '自分', '軍事', '銅貨', '割れる', '荒れる', '僅か', '慣れる', '響く', '出版', '雷', '翻案', '使用', '病気', '珍しい', '単純', '統一', '以来', '国土', '期間', '本人', '中央', '赤い', '遅れる', '部', '進む', '飲む', '大きい', '安心', '豆', '馬', '高い', '自己', '負ける', '描く', '都合', '前', '刃', '本当', '処理', '専念', '建物', '振り', '伸ばす', '彼', '挨拶', '勤勉', '殿下', '強い', '一変', '進行', '掌握', '天才', '生', '転職', '朝', '受ける', '鈍い', '立場', '内容', '昔', '語る', '厚手', '留学', '底', '揃う', '皆', '勃発', '地区', '無駄', '装置', '間に合う', '勤める', '異変', '不意', '起こる', '向上', '興味', '寝る', '失敗', '無邪気', '属する', '顔', '立つ', '含む', '我が', '者', '居座る', '引っ張る', '当然', '職業', '掲げる', '突破', '紙', '利く', '闇', '放送', '壁際', '持ち主', '本書', '現在', '特徴', '俺', '使役', '側近', '証明', '新た', '変わる', '男女', '調査', '決まる', '緑', '動物', '集中', '普通', '難い', '普段', '志願', '他国', '最も', '派遣', '空', '払う', '誰', '同等', '抜群', '確実', '一理', '素晴らしい', '電源', '扉', '備える', '白い', '配慮', '見習い', '足音', '行商', '騒ぐ', '失う', '身', '黙る', '丸める', '鋭い', '頼む', '昼食', '完全', '入れる', '簡単', '豪華', '長い', '次々', '謙遜', '得', '自信', '人口', '間', '異論', '威力', '大事', '飛ぶ', '来る', '苦笑', '各地', '囲む', '職員', '決して', '始まる', '半年', '染みる', '正面', '実力', '想像', '奥', '豊富', '疑問', '下', '乏しい', '撤退', '本性', '親友', '奴', '年', '活動', '重い', '姿勢', '深夜', '気', '急', '空間', '休み', '時期', '椅子', '狙う', '侵略', '崩れる', '器', '差し支える', '険しい', '私', '申す', '著作', '忙しい', '偉い', '考える', '依頼', '部屋', '怒る', '隠す', '無事', '言う', '存在', '会う', '続き', '会談', '天井', '覗く', '通り', '酒場', '十', '最近', '返る', '古い', '気味', '隣接', '掴む', '放る', '起こす', '恐れる', '召喚', '願う', '支部', '鎧', '打つ', '身長', '教会', '水産', '非難', '会社', '革', '成熟', '構える', '後半', '丸い', '笑み', '悪い', '短い', '踏む', 'お前', '直接', '帝国', '覇権', '成長', '失望', '明らか', '当たる', '謝る', '嘆く', '鍛える', '売れる', '才能', '挑戦', '妙', '貰う', '惜しむ', '架空', '少し', '電子', '働く', '放つ', '帰属', '百', '本来', '面', '扱う', '体重', '命令', '秒', '顎', '視線', '立てる', '指導', '受付', '緩い', '少年', '積む', '迫る', '経験', '流れる', '吸い込む', '経つ', '国王', '使い', '小', '興奮', '始末', '高', '背負う', '分散', '最初', '長年', '実績', '比べる', '漏らす', '下ろす', '製品', '負担', '女性', '納得', '弱い', '有名', '厳しい', '一体', '呼ぶ', '戦闘', '苦戦', '早々', '付ける', '様', '文章', '街道', '常識', '増やす', '上がる', '人間', '登録', '開く', '南', '呪文', '確信', '障壁', '丸', '限界', '探す', '似合う', '表面', '世界', '全然', '判明', '気候', '無くなる', '兄', '夜', '降る', '配信', '用事', '実用', '反応', '迷惑', '掲載', '大嫌い', '外見', '新人', '驚き', '貴族', '承諾' ...
# to add:	 427 {'業火', '悪鬼', '職探し', '黄金色', '転機', 'ラ王', '要求', '予', '造詣', '転送', '称', '閑話', '刷', '是', '製本', '押し開く', '北端', '過労', 'かじ取り', '火種', '面食らう', 'ㄈㄨ', '家臣', '真っ', '無い', '=', '肥沃', '思いの外', '旨い', '吹き上げる', '十全', '合本', '読', '€', '教導', '話し掛ける', '見目', 'こちら側', '目覚まし', '感服', '暗転', '権謀', '執務', '嫌み', '過ぎ', '押し出す', '語', '売国', '思いっきり', '呻く', '徹', '執り行なう', '総取り', '◆', 'そう伝聞', '駆け寄る', '広々', '････', '縁取る', '立', '総じて', '人となり', '何に', '異', '初々しい', '猪', '見遣る', '自適', '奮起', '造り', '☑', '遠目', '舞い上がる', '賢君', '政争', '体つき', '生来', '燻る', '控えめ', '助', '回', '鳥羽', '熟す', '当', '呉れる', '繋がり', '同じく', '索敵', '喉元', '小間使い', '高々', '仰る', '叩きのめす', '憎たらしい', '揺らす', '后', '時化る', '詰み', '観', '立ち込める', 'だらし無い', '他所', '否々', '主君', '轟音', 'まん丸', '宜しい', '動ずる', '臨', '+', '望み', '召使い', '･', '突き付ける', '素知らぬ', '◇', '問い掛ける', '見合う', '着心地', '涼やか', '鳴らす', '問いかけ', '吹', '結界', '立身', '装', '〜', '居る', '©', '後頭', '耳慣れる', '再', '踏み付ける', '吐息', '問', '転げ落ちる', '片鱗', '重用', '石造り', '底辺', '嬢', '×', '祝勝', '賭する', '旨味', '佐野', '手間賃', '大きな', '数段', '可愛い', '爆裂', '因る', '纏う', '片', '分断', '待ちぼうけ', '特に', '大一', '五千', '有る', '呼び掛ける', '不敬', '商家', '常々', '近', '室', '締めくくり', '書', '立ち上げる', '歯ぎしり', '･･････', '益体', '弱小', '屋', '渦巻く', '込み上げる', '転身', '雪景', '聖', '申しわけ', '栄', '数十', '童', '目つき', '三弥', '食い入る', '思い切る', '等分', '·', '起動', '礫', '声音', '突っ撥ねる', '訪れ', '自失', '誉', '突っ伏す', '秀', '大騒ぎ', '出で立ち', '喧騒', '賢者', '破竹', '絨毯', 'むき出し', '締め直す', '敷き詰める', '第', '腐', '苦言', '十分', '落ちこぼれ', '超', '跳び', '腕組み', '御座る', '腰掛ける', '酔狂', '貸し切る', '見越す', '勇者', '識', '羊皮', '決別', '最北', '模する', '話し合い', '出でる', '%', '混ざり合う', '預かる', '黒い', '格上', '入り口', '乗り切る', '撥ね除ける', '黒髪', '入れ替わる', '才気', '敬礼', '暴発', '師', '親父', '淳', '容体', '有り難い', '沈痛', '質感', '魔導', '吊り下がる', '報せ', '田舎暮らし', '見下す', '煩わす', '何故', '出来事', '官', '詫び', '華やぐ', '礼', '上程', '感', '―', '見透かす', '肉食', '消し飛ぶ', '災厄', '案ずる', '優', '勘気', '我', '突き詰める', '打ち明ける', '両輪', '深々', '突き当たり', '幼馴染', '付き添う', '久々', '强乱', '傾倒', '赤茶ける', 'この世', '優等', '楕円', '有り難う', '堪る', '次代', '丁', '王太子', '突き出す', '密偵', '於く', '見付かる', '亜人', '六百', '木っ端', '怪訝', '人外', '延', '品位', '詬', '最', '頃', 'Ő', '易々', '風花', '某', '譲', '食する', '受け取り', '繋がる', '板挟み', '貸', '突き返す', '魔物', '然う然う', '切れる', '素直', '隷', '走り去る', '奥まる', '為る', '遣る', '武官', '助かる', '霊薬', '職', '消え失せる', '媚びる', '余る', '୪', '諸島', '納品', '二十', '羽織る', '番う', '差さる', '१०१', '牽引', '肢', '脱力', '定', '名君', '持ち帰る', '☐', '←', 'ㄖ', '瞑目', '弱め', '翡翠', 'また上', '間違い', '文官', '違える', '今日は', '右上', '･･･', '未', '書き下ろし', '貧国', '少', '削れる', '蹴り飛ばす', '御早う', '遥か', '冷やかし', '可憐', '世迷いごと', '摂政', '今しがた', '起', '逃す', '打っ飛ばす', '仕方無い', '漉す', '仁徳', '支え', '術数', '見向く', '嘆き', '鼻面', '頷き合う', '安堵', '流石', '覗き込む', '温かい', '豪商', '傍', '陣', '恭しい', '吹き抜け', '哀れみ', '抱き付く', '恵み', 'そう様態', '滾つ', '特等', '側', '全', '指折り', '落ち', '見据える', '染め上げる', '化', '六本木', '気取り', '見開く', '魔力', '剥がす', '一気', '下限', '振るう', '並', '無性', '片眉', '同', '手掛ける', '実害', '精版', '冨山', '畏まる', 'なり断定', '✓', '登用', '変わり者', '助け'}
# to skip:	 16 {'力強い', '退ける', '弱る', '肩書', '深まる', '小国', '受け', '根強い', '成し遂げる', '切り替え', '感ずる', '現われる', '喜ばしい', '不味い', '押し付ける', '囲う'}
# failed:	 0 []
# --
# wf_kt,	Easy Words: 580 ['予', '伸', '称', '刷', '是', '=', '読', '€', '負', '語', '徹', '◆', '立', '異', '☑', '助', '回', '当', '后', '観', '臨', '+', '･', '◇', '吹', '装', '〜', '©', '再', '問', '嬢', '×', '片', '素', '近', '室', '書', '館', '屋', '座', '聖', '栄', '童', '·', '礫', '誉', '秀', '第', '腐', '超', '識', '%', '師', '判', '官', '礼', '感', '―', '優', '我', '丁', '延', '詬', '最', '頃', 'Ő', '譲', '貸', '隷', '職', '୪', '関', '肢', '定', '☐', '←', 'ㄖ', '峰', '未', '少', '起', '代', '傍', '陣', '側', '全', '化', '並', '同', '✓', '業火', '悪鬼', '金貨', '転機', '素質', 'ラ王', '要求', '一定', '契機', '造詣', '転送', '筋力', '製本', '近々', '不毛', '北端', '過労', '軍部', '実地', '火種', '随一', 'ㄈㄨ', '商業', '家臣', '真っ', '無い', '意地', '新規', '旨い', '十全', '合本', '全土', '教導', '見目', '感服', '暗転', '権謀', '執務', '調達', '嫌み', '過ぎ', '売国', '呻く', '奇異', '裁定', '山脈', '広々', '体質', '何に', '自適', '奮起', '来訪', '半ば', '造り', '五十', '遠目', '賢君', '政争', '中庭', '生来', '真似', '占領', '聖堂', '鳥羽', '建国', '熟す', '資質', '索敵', '喉元', '開放', '言及', '高々', '仰る', '個室', '体裁', '薬草', '詰み', '強気', '他所', '否々', '暴走', '鼻息', '主君', '轟音', '交易', '反る', '望み', '通路', '一心', '次期', '結界', '立身', '居る', '後頭', '吐息', '歴代', '交差', '醜悪', '書類', '重用', '底辺', '祝勝', '持ち', '適性', '旨味', '佐野', '一流', '数段', '爆裂', '因る', '国体', '纏う', '分断', '当分', '特に', '大一', '五千', '有る', '文面', '気質', '接近', '不敬', '商家', '常々', '宝玉', '一層', '称号', '書簡', '靡く', '直撃', '益体', '弱小', '来客', '盛ん', '一室', '転身', '雪景', '数十', '静脈', '運び', '視界', '開花', '君主', '人目', '東方', '等分', '起動', '声音', '訪れ', '自失', '喧騒', '賢者', '破竹', '内政', '駐留', '有無', '苦言', '十分', '穿つ', '跳び', '水晶', '動脈', '酔狂', '勇者', '羊皮', '強固', '決別', '最北', '黒い', '実体', '格上', '大使', '病状', '黒髪', '軽々', '才気', '敬礼', '暴発', '親父', '容体', '沈痛', '質感', '魔導', '名目', '報せ', '本国', '筆頭', '解体', '何故', '駐在', '詫び', '政務', '口数', '上程', '肉食', '災厄', '先端', '勘気', '間近', '両輪', '深々', '久々', '强乱', '傾倒', '優等', '堪る', '次代', '侵攻', '密偵', '達人', '装飾', '亜人', '六百', '人外', '品位', '易々', '主従', '風花', '魔物', '集う', '旅人', '驚異', '素直', '要人', '為る', '遣る', '武官', '霊薬', '余る', '回廊', '手配', '諸島', '納品', '二十', '番う', '粗野', '停滞', '脱退', '脱力', '名君', '弱め', '濃紺', '文官', '国政', '満喫', '右上', '小川', '貧国', '苦い', '向き', '大国', '付与', '一角', '摂政', '逃す', '洗練', '目下', '仁徳', '支え', '術数', '嘆き', '鼻面', '突く', '流石', '豪商', '恵み', '意気', '対処', '襟元', '滾つ', '特等', '落ち', '背骨', '口調', '鉄板', '魔力', '立地', '大物', '決戦', '一気', '下限', '無性', '亡者', '片眉', '名物', '物陰', '相当', '実害', '精版', '登用', '助け', '職探し', '黄金色', '為さる', '言い分', '総取り', '縁取る', '総じて', '見遣る', '体つき', '控えめ', '繋がり', '同じく', '揺らす', '時化る', '眼差し', 'まん丸', '宜しい', '動ずる', '召使い', '見合う', '着心地', '涼やか', '鳴らす', '足取り', '表わす', '石造り', '砕ける', '賭する', '手間賃', '大きな', '軽やか', '可愛い', '渦巻く', '柔らか', '目つき', '大騒ぎ', '腕組み', '御座る', '見越す', '模する', '出でる', '分け前', '預かる', '行き来', '入り口', '荒らす', '見下す', '煩わす', '傾げる', '出来事', '華やぐ', '案ずる', '幼馴染', 'この世', '王太子', '発する', '身なり', '木っ端', '存ずる', '食する', '繋がる', '板挟み', '切れる', '奥まる', '助かる', '顔立ち', '羽織る', '差さる', '१०१', 'また上', '間違い', '悔やむ', '違える', '今日は', '･･･', '削れる', '御早う', '見向く', '温かい', '信ずる', '哀れみ', '指折り', '六本木', '気取り', '見開く', '剥がす', '振るう', '押し開く', 'かじ取り', '面食らう', '思いの外', '向こう側', 'こちら側', '目覚まし', '押し出す', '辿り着く', 'そう伝聞', '駆け寄る', '････', '取り残す', '人となり', '初々しい', '小間使い', '素知らぬ', '問いかけ', '耳慣れる', '差し出す', '聞き返す', '立ち読み', '聞き取る', '歯ぎしり', '相応しい', '申しわけ', '食い入る', '思い切る', '突っ伏す', '出で立ち', 'むき出し', '締め直す', '引き渡す', '腰掛ける', '飛び込む', '貸し切る', '話し合い', '乗り切る', '言葉遣い', '有り難い', '見透かす', '消し飛ぶ', '付き添う', '赤茶ける', '有り難う', '突き出す', '見付かる', '受け取り', '突き返す', '請け負う', '置き去り', '然う然う', '走り去る', '清々しい', '言い切る', '押し込む', '持ち帰る', '冷やかし', '今しがた', '入り込む', '仕方無い', '頷き合う', '覗き込む', '吹き抜け', '抱き付く', 'そう様態', '見据える', '張り出す', '手掛ける', 'なり断定', '見付ける', '変わり者', '起き上がる', '吹き上げる', '話し掛ける', '思いっきり', '執り行なう', '取り掛かる', '舞い上がる', '叩きのめす', '憎たらしい', '差し掛かる', '立ち込める', 'だらし無い', '突き付ける', '問い掛ける', '踏み付ける', '転げ落ちる', '待ちぼうけ', '呼び掛ける', '締めくくり', '立ち上げる', '込み上げる', '突っ撥ねる', '敷き詰める', '落ちこぼれ', '混ざり合う', '撥ね除ける', '入れ替わる', '吊り下がる', '田舎暮らし', '突き詰める', '打ち明ける', '突き当たり', '消え失せる', '書き下ろし', '蹴り飛ばす', '世迷いごと', '打っ飛ばす', '染め上げる', '浮かび上がる', '･･････']
# wf_kf,	Low Prio Word: 27 {'呉れる', '芳しい', '終焉', '安堵', '楕円', '絨毯', '猪', '牽引', '恭しい', '漆黒', '閑話', '於く', '遥か', '淳', '瞑目', '怪訝', '片鱗', '可憐', '翡翠', '冨山', '畏まる', '三弥', '燻る', '媚びる', '肥沃', '某', '漉す'}
# wt_kf,	High Prio Kanji: 0 set()
# wt_kt,	Known Words: 1251 ['息', '元', '口', '大', '実', '性', '何', '青', '膝', '他', '堂', '番', '光', '件', '血', '三', '力', '冬', '床', '勘', '無', '逆', '方', '民', '王', '一', '湖', '柱', '西', '新', '後', '係', '東', '雲', '名', '横', '腕', '芸', '球', '六', '人', '噂', '変', '山', '体', '袖', '版', '時', '背', '等', '四', '舎', '声', '花', '嵐', '軍', '手', '席', '雷', '部', '豆', '馬', '前', '刃', '彼', '生', '朝', '昔', '底', '皆', '顔', '者', '紙', '闇', '俺', '緑', '空', '誰', '扉', '身', '得', '間', '奥', '下', '奴', '年', '気', '急', '器', '私', '十', '鎧', '革', '妙', '百', '面', '秒', '顎', '小', '高', '様', '南', '丸', '兄', '夜', '念', '鼻', '隣', '杖', '机', '権', '分', '姿', '首', '縄', '倍', '嘘', '非', '八', '音', '次', '五', '共', '暁', '胸', '千', '区', '日', '所', '用', '今', '外', '術', '数', '敵', '道', '指', '御', '肩', '北', '金', '台', '港', '比', '的', '万', '家', '訳', '点', '岩', '行', '袋', '魔', '塊', '会', '黒', '玉', '夢', '剣', '章', '枚', '足', '街', '父', '心', '髪', '目', '腰', '差', '耳', '男', '服', '齢', '品', '国', '欄', '獣', '頬', '否', '仮', '天', '初', '子', '女', '唾', '中', '内', '炎', '話', '場', '壁', '先', '瞳', '色', '額', '度', '意', '瞼', '都', '頭', '二', '位', '板', '例', '上', '月', '妹', '別', '法', '七', '飯', '尻', '森', '春', '号', '九', '物', '暇', '平常', '同じ', '健康', '身分', '押す', '人生', '代金', '東部', '属性', '最高', '風景', '本格', '処置', '入る', '相手', '表情', '凄い', '政治', '送る', '体力', '詠唱', '玄関', '成立', '難易', '仕方', '成る', '感情', '幸い', '執筆', '許諾', '順番', '行く', '新刊', '動く', '最低', '将来', '背景', '動作', '規模', '仕草', '企業', '利用', '生活', '感じ', '移動', '精霊', '一筋', '予想', '重量', '即座', '廊下', '大変', '案外', '近い', '午後', '赤字', '反発', '割合', '荒い', '訓練', '病院', '示す', '乗る', '互い', '一大', '不審', '王子', '運動', '装備', '愚痴', '土地', '勝つ', '直後', '報告', '気分', '心配', '騙す', '類い', '死ぬ', '妨害', '一員', '隣国', '現状', '結構', '毎年', '従う', '真剣', '笑う', '国内', '王女', '退屈', '満足', '変化', '内外', '済む', '報酬', '頷く', '画面', '話す', '傍ら', '噛む', '疑う', '期待', '着る', '出世', '作る', '必ず', '授与', '通用', '陛下', '基本', '産業', '呆然', '行う', '自体', '零す', '気配', '安全', '年間', '口絵', '身体', '通る', '思う', '重厚', '情報', '輝き', '日本', '決意', '大型', '皇帝', '急ぐ', '緊張', '思想', '誕生', '優先', '遊ぶ', '練る', '見事', '貧乏', '日常', '一方', '譲る', '懸念', '豊か', '少々', '取る', '好く', '妄想', '臨時', '協力', '時間', '途端', '辛い', '会話', '掲示', '無理', '貴重', '大半', '規格', '易い', '兵隊', '挟む', '初代', '絡む', '減る', '削る', '笑顔', '広い', '至る', '近く', '不足', '振る', '許可', '対応', '就職', '聞く', '請求', '馬鹿', '経過', '殺す', '歴史', '個人', '関節', '採取', '余裕', '元々', '想定', '争う', '適正', '返答', '更新', '頂く', '株式', '結論', '意見', '初心', '厄介', '掻く', '買う', '遠方', '組織', '自分', '軍事', '銅貨', '僅か', '響く', '出版', '翻案', '使用', '病気', '単純', '統一', '以来', '国土', '期間', '本人', '中央', '赤い', '進む', '飲む', '安心', '高い', '自己', '描く', '都合', '本当', '処理', '専念', '建物', '振り', '挨拶', '勤勉', '殿下', '強い', '一変', '進行', '掌握', '天才', '転職', '鈍い', '立場', '内容', '語る', '厚手', '留学', '揃う', '勃発', '地区', '無駄', '装置', '異変', '不意', '向上', '興味', '寝る', '失敗', '立つ', '含む', '我が', '当然', '職業', '突破', '利く', '放送', '壁際', '本書', '現在', '特徴', '使役', '側近', '証明', '新た', '男女', '調査', '動物', '集中', '普通', '難い', '普段', '志願', '他国', '最も', '派遣', '払う', '同等', '抜群', '確実', '一理', '電源', '白い', '配慮', '足音', '行商', '騒ぐ', '失う', '黙る', '鋭い', '頼む', '昼食', '完全', '簡単', '豪華', '長い', '次々', '謙遜', '自信', '人口', '異論', '威力', '大事', '飛ぶ', '来る', '苦笑', '各地', '囲む', '職員', '半年', '正面', '実力', '想像', '豊富', '疑問', '撤退', '本性', '親友', '活動', '重い', '姿勢', '深夜', '空間', '休み', '時期', '椅子', '狙う', '侵略', '申す', '著作', '偉い', '依頼', '部屋', '怒る', '隠す', '無事', '言う', '存在', '会う', '続き', '会談', '天井', '覗く', '通り', '酒場', '最近', '返る', '古い', '気味', '隣接', '掴む', '放る', '召喚', '願う', '支部', '打つ', '身長', '教会', '水産', '非難', '会社', '成熟', '後半', '丸い', '笑み', '悪い', '短い', '踏む', 'お前', '直接', '帝国', '覇権', '成長', '失望', '謝る', '嘆く', '才能', '挑戦', '貰う', '架空', '少し', '電子', '働く', '放つ', '帰属', '本来', '扱う', '体重', '命令', '視線', '指導', '受付', '緩い', '少年', '積む', '迫る', '経験', '経つ', '国王', '使い', '興奮', '始末', '分散', '最初', '長年', '実績', '製品', '負担', '女性', '納得', '弱い', '有名', '一体', '呼ぶ', '戦闘', '苦戦', '早々', '文章', '街道', '常識', '人間', '登録', '開く', '呪文', '確信', '障壁', '限界', '探す', '表面', '世界', '全然', '判明', '気候', '降る', '配信', '用事', '実用', '反応', '迷惑', '掲載', '外見', '新人', '驚き', '貴族', '承諾', '暗い', '出現', '人物', '売る', '得意', '全体', '失礼', '追加', '老人', '扱い', '東京', '培う', '連続', '討伐', '複製', '停止', '吐く', '文字', '背筋', '拘束', '選択', '評判', '先日', '起伏', '金色', '構成', '転生', '戻る', '署名' ...
# UNNEEDED (SKIP): 	 16 ['弱る', '肩書', '小国', '受け', '囲う', '力強い', '退ける', '深まる', '根強い', '感ずる', '不味い', '切り替え', '現われる', '喜ばしい', '成し遂げる', '押し付ける']

# %% [markdown]
# # (batch add)
# - anki batch add (+ more custom tags)
# - save results to a text file (-2,-1,0,1,2)
#
#
# Is JISHO is slow?:
# - 142 -> 37min, 156 -> 32min, 128 -> 24min, 102 -> 23min.
# - -> in total for 528 words -> avg 13.32 seconds per addition
# - Need another card creation api, maybe look into how yomitan does it?
# - bottleneck may just be Anki though.
# - and our way of Anki SCHEDULING, not adding cards
# - maybe somehow we can parallelize scheduling?

# %%
"""
def create_furigana(word, reading):
    return "{}[{}]".format(word, reading)


def create_meaning(meanings):
    meaning_field = []
    for definition in meanings:
        defs = []
        for word in definition.english_definitions:
            defs.append(word)
            # print(word)
        one_def = ", ".join(defs)
        meaning_field.append(one_def)
    return f" (*) ".join(meaning_field)
"""
# no jisho
# Out:
# '\ndef create_furigana(word, reading):\n    return "{}[{}]".format(word, reading)\n\n\ndef create_meaning(meanings):\n    meaning_field = []\n    for definition in meanings:\n        defs = []\n        for word in definition.english_definitions:\n            defs.append(word)\n            # print(word)\n        one_def = ", ".join(defs)\n        meaning_field.append(one_def)\n    return f" (*) ".join(meaning_field)\n'

# %% [markdown]
# ## setup dictionary

# %%
JITENDEX_PATH = "/nav/jitendex-yomitan/"

def load_entire_dict():
    results = []
    cached_ranges = defaultdict(list)
    for filename in os.listdir(JITENDEX_PATH):
        if filename.endswith('.json') and "term_bank" in filename:
            filepath = os.path.join(JITENDEX_PATH, filename)
            with open(filepath, 'r', encoding='utf-8') as file:
                data = json.load(file)
                start_index = len(results)

                results.extend(data)

                end_index = len(results)
                cached_ranges[filename] = [start_index, end_index]
    return results, cached_ranges

data, cached_ranges = load_entire_dict()

# %%
def word_comparator(word_data1, word_data2):
    word1 = word_data1[1]
    word2 = word_data2[1]
    # Normalize katakana to hiragana
    def normalize(word):
        return ''.join(
            chr(ord(char) - 0x60) if 'ァ' <= char <= 'ン' else char
            for char in word
        )
    word1 = normalize(word1)
    word2 = normalize(word2)
    return (word1 > word2) - (word1 < word2)

# %%
# %%time
sorted_dataset = sorted(data, key=functools.cmp_to_key(word_comparator))
len(sorted_dataset)
# Out:
# CPU times: total: 12.4 s
# Wall time: 13.3 s
# 299921

# %%
# V2, handles data content glossary 
def extract_definitions(json_obj):
    """
    Extract definitions from a JSON structure where 'data -> content -> glossary' acts as the marker.

    Args:
        json_obj: The JSON object to search (can be a dict or list).

    Returns:
        A list of definitions found under the specified path.
    """
    definitions = []

    def recursive_search(obj):
        if isinstance(obj, dict):
            # Check if this dict contains the specific marker
            if (
                "data" in obj
                and isinstance(obj["data"], dict)
                and obj["data"].get("content") == "glossary"
                and "content" in obj
            ):
                # Extract the 'content' under this structure
                glossary_content = obj["content"]
                if isinstance(glossary_content, list):
                    # Collect all the 'content' fields from the glossary list
                    for item in glossary_content:
                        if isinstance(item, dict) and "content" in item:
                            definitions.append(item["content"])
                elif isinstance(glossary_content, dict):
                    # Single dictionary case (e.g., "welcome!")
                    if "content" in glossary_content:
                        definitions.append(glossary_content["content"])
            else:
                # Continue searching deeper in the dict
                for key, value in obj.items():
                    recursive_search(value)
        elif isinstance(obj, list):
            # Search each item in the list
            for item in obj:
                recursive_search(item)

    # Start the recursive search
    recursive_search(json_obj)
    return definitions

# redirect one.
def extract_redirect(json_obj):
    """
    # path for redirect -> 5, content, content (base), ⟶
    # field: (base), 1, content
    """
    # print(len(json_obj[5][0]['content']))
    # print(json_obj[5][0]['content'][0])
    # print(json_obj[5][0]['content'][1])
    if (isinstance(json_obj, list) and 
        isinstance(json_obj[5], list) and 
        isinstance(json_obj[5][0], dict) and 
        isinstance(json_obj[5][0]['content'], dict)):
        base = json_obj[5][0]['content']['content']
    else:
        # print("not based")
        return []
    if base[0] == "⟶":
        field_base = base[1]['content']
        if isinstance(field_base, list):
            return [field_base[0]]
        elif isinstance(field_base, str):
            return [field_base]
        elif isinstance(field_base, dict):
            return field_base['content'][0]
        else: 
            return []
    else: 
        
        return []
    
def extract_explanation(json_obj):
    """
    Only 39 left out of 300k. Not a priority.
    """
    pass

# %%
cached_index = defaultdict(list)

dup = 0
for i, word in enumerate(sorted_dataset):
    cached_index[word[0]].append(i)

print(sum(len(v) for k, v in cached_index.items()) == len(data))

CACHE_FILE = "my_cached_index.json"
with open(os.path.join(JITENDEX_PATH, CACHE_FILE), "w", encoding="utf-8") as json_file:
    json.dump(cached_index, json_file, indent=4)

# Read from file
with open(os.path.join(JITENDEX_PATH, CACHE_FILE), "r", encoding="utf-8") as json_file:
    cache = json.load(json_file)

print(sum(len(v) for k, v in cache.items()) == len(data))
# Out:
# True
# True

# %% [markdown]
# generate cards

# %%
def generate_fields_with_jitendex(word, ds):
    """
    Get fields
    """
    readings = []
    
    if word not in cache:
        # Return none for now...
        # Could use binary search but there are problems
        # 1) have to check if the word is kana only
        # 2) words like そば could either be 傍　蕎麦　側
        return None
    else:
        for index in cache[word]:
            word_info = ds[index]
            yomigana = word_info[1]
            assert word == word_info[0]
            defs = extract_definitions(word_info)
            if defs is None:
                defs = extract_redirect(word_info)
            if defs is None:
                defs = extract_explanation(word_info)
            readings.append(f"{word}[{yomigana}]")
        
        furigana = " / ".join(readings)
        meaning = ", ".join(defs)

    return word, furigana, meaning

# %% [markdown]
# ## anki connect modifications
#
#
# C:\Users\Evan\AppData\Roaming\Anki2\addons21\2055492159\__init__.py

# %%
try:
    # ===================================================== (EBUI) THIS PART IS EDITED BY ME
    @util.api()
    def setSpecificValueOfCards(self, cards, keys, newValues, warning_check=True):
        """"""
        if not isinstance(cards, list) or not all(isinstance(card,int) for card in cards):
            print("card must be a list of ints")
            return False
        
        if not isinstance(keys, list) or not isinstance(newValues, list):
            print("keys and newValues have to be lists.")
            return False

        if len(newValues) != len(keys):
            print("Invalid list lengths.")
            return False

        for key in keys:
            if key in ["did", "id", "ivl", "lapses", "left", "mod", "nid",
                    "odid", "odue", "ord", "queue", "reps", "type", "usn"]:
                if warning_check is False:
                    return False

        result = []
        try:
            ankiCards = [self.getCard(card) for card in cards]
            for ankiCard in ankiCards:
                for i, key in enumerate(keys):
                    setattr(ankiCard, key, newValues[i])

            self.collection().update_cards(ankiCards, skip_undo_entry=True)
            result.append(True)
        except Exception as e:
            result.append([False, str(e)])
        return result

    # ===================================================== (EBUI) THIS PART IS EDITED BY ME
    # ===================================================== (EBUI) THIS PART IS EDITED BY ME
    def createNotesSkipChecks(self, notes, skip_checks) -> list[AddNoteRequest]:
        if len(notes) == 0: return []
        
        collection = self.collection()

        model = collection.models.by_name(notes[0]['modelName'])
        if model is None:
            raise Exception('model was not found: {}'.format(notes[0]['modelName']))

        deck = collection.decks.by_name(notes[0]['deckName'])
        if deck is None:
            raise Exception('deck was not found: {}'.format(notes[0]['deckName']))

        requests = []
        for note in notes:
            ankiNote = anki.notes.Note(collection, model)
            ankiNote.note_type()['did'] = deck['id']
            if 'tags' in note:
                ankiNote.tags = note['tags']

            for name, value in note['fields'].items():
                for ankiName in ankiNote.keys():
                    if name.lower() == ankiName.lower():
                        ankiNote[ankiName] = value
                        break

            self.addMediaFromNote(ankiNote, note)


            # CHECKS, 
            if skip_checks:
                requests.append(AddNoteRequest(ankiNote, deck['id']))
            else:
                allowDuplicate = False
                duplicateScope = None
                duplicateScopeDeckName = None
                duplicateScopeCheckChildren = False
                duplicateScopeCheckAllModels = False

                if 'options' in note:
                    options = note['options']
                    if 'allowDuplicate' in options:
                        allowDuplicate = options['allowDuplicate']
                        if type(allowDuplicate) is not bool:
                            continue
                    if 'duplicateScope' in options:
                        duplicateScope = options['duplicateScope']
                    if 'duplicateScopeOptions' in options:
                        duplicateScopeOptions = options['duplicateScopeOptions']
                        if 'deckName' in duplicateScopeOptions:
                            duplicateScopeDeckName = duplicateScopeOptions['deckName']
                        if 'checkChildren' in duplicateScopeOptions:
                            duplicateScopeCheckChildren = duplicateScopeOptions['checkChildren']
                            if type(duplicateScopeCheckChildren) is not bool:
                                continue
                        if 'checkAllModels' in duplicateScopeOptions:
                            duplicateScopeCheckAllModels = duplicateScopeOptions['checkAllModels']
                            if type(duplicateScopeCheckAllModels) is not bool:
                                continue

                duplicateOrEmpty = self.isNoteDuplicateOrEmptyInScope(
                    ankiNote,
                    deck,
                    collection,
                    duplicateScope,
                    duplicateScopeDeckName,
                    duplicateScopeCheckChildren,
                    duplicateScopeCheckAllModels
                )

                if duplicateOrEmpty == 1:
                    continue
                elif duplicateOrEmpty == 2:
                    if allowDuplicate:
                        requests.append(AddNoteRequest(ankiNote, deck['id']))
                    continue
                elif duplicateOrEmpty == 0:
                    requests.append(AddNoteRequest(ankiNote, deck['id']))
                else:
                    continue

        return requests

    @util.api()
    def addNotesSkipChecks(self, notes, skip_checks):
        """
        https://github.com/ankitects/anki/blob/9c3f89466d38d72daf8f671d6f3c8b18351bc642/pylib/anki/collection.py#L538
        """
        collection = self.collection()
        requests = self.createNotesSkipChecks(notes, skip_checks)
        self.collection().add_notes(requests)
        return len(requests)
    # ===================================================== (EBUI) THIS PART IS EDITED BY ME
except Exception:
    pass

# %% [markdown]
# ## critical code

# %%
# DECK_NAME = "-exp::anki-connect-test"
DECK_NAME = "nhg::3vocab::auto-unsorted"
NOTE_MODEL_NAME = "2-Vocab"

def create_note(word, deck_name=DECK_NAME, generation_method="jitendex", tags=[], allow_same=True, force_generate=False):
    """
    Generalize creating a note

    Args:
        deck_name: name of deck to generate to
        generateion_method: jitendex or jisho
        tags: extra tags to tag the note with
        allow_same: is for same words with different kanji
        force_generate: generate cards that are not found
        
    Returns:
        return code
        -2 - Error
        -1 - Not Found
        0 - already in deck
        else: card_id integer
    """
    note = dict()
    note["deckName"] = deck_name
    note["modelName"] = NOTE_MODEL_NAME
    note["tags"] = ["autocreated"]

    """
    Fields to fill out: 
    Word
    Furigana
    Meaning
    """


    print("Creating card for:", word)
    fields = {}

    if generation_method == "jisho":
        raise NotImplementedError
    elif generation_method == "jitendex":
        word_info = generate_fields_with_jitendex(word, sorted_dataset)
    else:
        print("Generation method is not implemented")
        raise NotImplementedError

    # Fill in fields
    if word_info:
        fields["Word"] = word_info[0]
        fields["Furigana"] = word_info[1]
        fields["Meaning"] = word_info[2]
    elif word_info is None and force_generate == True:
        fields["Word"] = word
    else:
        return -1

    note["fields"] = fields
    # AnkiConnect request
    try:
        result = invoke("addNote", note=note)
        # ANKI API HAS add_notes 
        
    except Exception as e:
        # maybe we should utilize this and not get the card ID before hand 
        if str(e) == "cannot create note because it is a duplicate":
            print("Cannot create note because it is duplicate")
            return 0
        else:
            raise

    return result

# %%
def create_notes(words, deck_name=DECK_NAME, generation_method="jitendex", tags=[], allow_same=True, force_generate=False, skip_checks=False):
    """
    dupe checking doesn't actually take long so don't ever skip checks lol
    WARNING: CREATES DUPES if skip_checks == True

    Generalize creating a note

    Args:
        deck_name: name of deck to generate to
        generateion_method: jitendex or jisho
        tags: extra tags to tag the note with
        allow_same: is for same words with different kanji
        force_generate: generate cards that are not found
        
    Returns:
        return code
        -2 - Error
        -1 - Not Found
        0 - already in deck
        else: card_id integer
    """
    notes = []
    not_found = []

    for word in words:
        note = dict()
        note["deckName"] = deck_name
        note["modelName"] = NOTE_MODEL_NAME
        note["tags"] = ["autocreated"]

        """
        Fields to fill out: 
        Word
        Furigana
        Meaning
        """


        print("Creating card for:", word)
        fields = {}

        if generation_method == "jisho":
            raise NotImplementedError
        elif generation_method == "jitendex":
            word_info = generate_fields_with_jitendex(word, sorted_dataset)
        else:
            print("Generation method is not implemented")
            raise NotImplementedError

        # Fill in fields
        if word_info:
            fields["Word"] = word_info[0]
            fields["Furigana"] = word_info[1]
            fields["Meaning"] = word_info[2]
        elif word_info is None and force_generate == True:
            fields["Word"] = word
        else:
            not_found.append(word)
            continue

        note["fields"] = fields
        notes.append(note)

    # AnkiConnect request
    try:
        result = invoke("addNotesSkipChecks", notes=notes, skip_checks=skip_checks)
        # ANKI API HAS add_notes 
    except Exception as e:
        raise
        # maybe we should utilize this and not get the card ID before hand 
        if str(e) == "cannot create note because it is a duplicate":
            print("Cannot create note because it is duplicate")
            return 0
        else:
            raise

    return result, not_found

# %%
query = "deck:-exp::anki-connect-test Word:じ"
# search_result = invoke("findCards", query=query)
def get_word_card_ids(query):
    search_result = invoke("findCards", query=query)
    return search_result

def get_word_card_id(word, query = None):
    # print("Finding card id for:", word)
    # maybe we can improve the query?
    # https://github.com/ankidroid/Anki-Android/wiki/Database-Structure
    # https://docs.ankiweb.net/searching.html
    # query = f"deck:nhg::3vocab Word:{word}"
    if not query:
        query = f"deck:nhg::3vocab prop:ivl=0 Word:{word}"
    search_result = invoke("findCards", query=query)
    # Should be no dupes...
    # assert len(search_result) == 1
    if len(search_result) == 0:
        # print("Skipping")
        return None
    return search_result[0]

# %%
VOCAB_DECK_CREATION_DATE = date(2018, 5, 10)

def set_card_learned(card_id, ivl): # this is slightly inefficient if we are doing 1by1
    """
    https://git.foosoft.net/alex/anki-connect/src/commit/98e0bb35fb77fa3983347035f123065feb4c56e6/plugin/__init__.py
    Anki API:  
        self.collection().update_card(ankiCard, skip_undo_entry=True)

    https://github.com/ankitects/anki/blob/main/rslib/src/storage/card/update_card.sql
        update_card

        https://github.com/ankitects/anki/blob/main/rslib/src/card/mod.rs   
    """
    keys = ["ivl", "type", "queue", "due"]

    delta = abs(date.today() - VOCAB_DECK_CREATION_DATE)
    due = ivl + delta.days
    due_date = VOCAB_DECK_CREATION_DATE + timedelta(days=due)
    newValues = [ivl, 2, 2, due]
    # ivl   -> how long between last and current review
    #       -> changes to time from current review to future review
    # type  -> ???? 2 is the correct one tho
    # queue -> ???? 2 is the correct one tho
    # due   -> days FROM deck creation to be due on (0 is deck creation day)
    
    

    result = invoke("setSpecificValueOfCard", card=card_id, keys=keys, newValues=newValues, warning_check=True)
    if result and result[0]: 
        return due_date
    return None

# %%
def set_cards_learned(card_ids: list[int], ivl: int) -> list[object]:
    """
    After years of training.
    """
    keys = ["ivl", "type", "queue", "due"]
    delta = abs(date.today() - VOCAB_DECK_CREATION_DATE)
    due = ivl + delta.days
    due_date = VOCAB_DECK_CREATION_DATE + timedelta(days=due)
    newValues = [ivl, 2, 2, due]

    result = invoke("setSpecificValueOfCards", cards=card_ids, keys=keys, newValues=newValues, warning_check=True)
    if result and result[0]: 
        return due_date
    return None

# %%
SKIP_DECK = "nhg::3vocab::unneeded"

def auto_add(word):
    """
    Create and check if can be scheduled

    Args:
        word: word
        ivl: interval to set for known word
        force_schedule: If true, sets due date to interval even if it's already learned
        skip_schedule: Do not schedule, only create the card
        wait_for_type: wait for card to be fully created or skip it

    Returns:
        return code
        -1 or 
        or card_id
    """
    print(f"--START-- auto_add -- {word}")
    if not word:
        return -1
    
    card_id = get_word_card_id(word)
    if not card_id:
        card_id = create_note(word)
    if card_id in {-2, -1}:
        return -1
        
    print(card_id)
    return card_id


def schedule(cards, ivl, force_schedule=False, skip_schedule=False):
    print(f"===== Start at: {datetime.now()}")
    print(len(cards))
    # check_card_unlearned
    cards_to_set = []
    key_error = []
    skipped = []
    if not force_schedule:
        cards_info = invoke("cardsInfo", cards=cards)
        print(len(cards_info))
        print(f"===== Finished getting cards: {datetime.now()}")
        for card_info in cards_info:
            try:
                if card_info["deckName"] == SKIP_DECK:
                    # print("Skipping scheduling. Not needed")
                    skipped.append(card_info)
                    continue
                if card_info["type"] or card_info["queue"]:
                    # print("Skipping scheduling. Not a new card")
                    # print("Card Interval:", card_info["interval"])
                    skipped.append(card_info) # this has to be the card id
                    continue
                cards_to_set.append(card_info["cardId"])
            except KeyError as e:
                # This just doesn't work on retry. Maybe due to some lock?
                # print(f"Key 'type' doesn't exist yet. Skipping. ")
                """
                THIS IS WHY IT DOESN'T WORK, race against the +1
                # @deprecated(replaced_by=add_note)
                def addNote(self, note: Note) -> int:
                    self.add_note(note, note.note_type()["did"])
                    return len(note.cards())
                """
                key_error.append(card_info["cardId"])
                continue
    print(f"Cards to schedule: {len(cards_to_set)}")
    print(f"Skipped due to key: {len(key_error)}")
    print(f"Skipped else: {len(skipped)}")
    print(f"===== Now scheduling cards: {datetime.now()}")
    results = set_cards_learned(cards_to_set, ivl)
    print(f"===== Finished scheduling cards: {datetime.now()}")
    return results, key_error, skipped

# %% [markdown]
# ## test new auto add -> then batch schedule
#
# auto add one by one is terribly inefficient:
# - get / findCards - not taking advantage of the duplicate checker
# - insert / addNote - one by one means N commits
#
#
# -> 32m 51s -> 1971s / 580w -> 3.4s (348 / 580 newly added -> 60%)
#
# -> 580w (all already added) -> 525 in end result (55 not found) -> 2.08s
#
# print progress instead of a comprehension
#
# weird edge case -> incorrect because there was a newline in the field:
# ```
# --START-- auto_add -- 要求
# Finding card id for: 要求
# Creating card for: 要求
# Cannot create note because it is duplicate
# 0
# ```
#
#
# after optimization: 580 -> (280 added) less than 3s

# %%
# %%time
words = easy
print(len(words))
# card_ids = list(filter(lambda cid: cid > 0, [auto_add(word) for word in words]))
# should not rely on create_note to return the cid.
results, not_found = create_notes(words, skip_checks=False)
print(results, len(not_found))
# Out:
# 580
# Creating card for: 予
# Creating card for: 伸
# Creating card for: 称
# Creating card for: 刷
# Creating card for: 是
# Creating card for: =
# Creating card for: 読
# Creating card for: €
# Creating card for: 負
# Creating card for: 語
# Creating card for: 徹
# Creating card for: ◆
# Creating card for: 立
# Creating card for: 異
# Creating card for: ☑
# Creating card for: 助
# Creating card for: 回
# Creating card for: 当
# Creating card for: 后
# Creating card for: 観
# Creating card for: 臨
# Creating card for: +
# Creating card for: ･
# Creating card for: ◇
# Creating card for: 吹
# Creating card for: 装
# Creating card for: 〜
# Creating card for: ©
# Creating card for: 再
# Creating card for: 問
# Creating card for: 嬢
# Creating card for: ×
# Creating card for: 片
# Creating card for: 素
# Creating card for: 近
# Creating card for: 室
# Creating card for: 書
# Creating card for: 館
# Creating card for: 屋
# Creating card for: 座
# Creating card for: 聖
# Creating card for: 栄
# Creating card for: 童
# Creating card for: ·
# Creating card for: 礫
# Creating card for: 誉
# Creating card for: 秀
# Creating card for: 第
# Creating card for: 腐
# Creating card for: 超
# Creating card for: 識
# Creating card for: %
# Creating card for: 師
# Creating card for: 判
# Creating card for: 官
# Creating card for: 礼
# Creating card for: 感
# Creating card for: ―
# Creating card for: 優
# Creating card for: 我
# Creating card for: 丁
# Creating card for: 延
# Creating card for: 詬
# Creating card for: 最
# Creating card for: 頃
# Creating card for: Ő
# Creating card for: 譲
# Creating card for: 貸
# Creating card for: 隷
# Creating card for: 職
# Creating card for: ୪
# Creating card for: 関
# Creating card for: 肢
# Creating card for: 定
# Creating card for: ☐
# Creating card for: ←
# Creating card for: ㄖ
# Creating card for: 峰
# Creating card for: 未
# Creating card for: 少
# Creating card for: 起
# Creating card for: 代
# Creating card for: 傍
# Creating card for: 陣
# Creating card for: 側
# Creating card for: 全
# Creating card for: 化
# Creating card for: 並
# Creating card for: 同
# Creating card for: ✓
# Creating card for: 業火
# Creating card for: 悪鬼
# Creating card for: 金貨
# Creating card for: 転機
# Creating card for: 素質
# Creating card for: ラ王
# Creating card for: 要求
# Creating card for: 一定
# Creating card for: 契機
# Creating card for: 造詣
# Creating card for: 転送
# Creating card for: 筋力
# Creating card for: 製本
# Creating card for: 近々
# Creating card for: 不毛
# Creating card for: 北端
# Creating card for: 過労
# Creating card for: 軍部
# Creating card for: 実地
# Creating card for: 火種
# Creating card for: 随一
# Creating card for: ㄈㄨ
# Creating card for: 商業
# Creating card for: 家臣
# Creating card for: 真っ
# Creating card for: 無い
# Creating card for: 意地
# Creating card for: 新規
# Creating card for: 旨い
# Creating card for: 十全
# Creating card for: 合本
# Creating card for: 全土
# Creating card for: 教導
# Creating card for: 見目
# Creating card for: 感服
# Creating card for: 暗転
# Creating card for: 権謀
# Creating card for: 執務
# Creating card for: 調達
# Creating card for: 嫌み
# Creating card for: 過ぎ
# Creating card for: 売国
# Creating card for: 呻く
# Creating card for: 奇異
# Creating card for: 裁定
# Creating card for: 山脈
# Creating card for: 広々
# Creating card for: 体質
# Creating card for: 何に
# Creating card for: 自適
# Creating card for: 奮起
# Creating card for: 来訪
# Creating card for: 半ば
# Creating card for: 造り
# Creating card for: 五十
# Creating card for: 遠目
# Creating card for: 賢君
# Creating card for: 政争
# Creating card for: 中庭
# Creating card for: 生来
# Creating card for: 真似
# Creating card for: 占領
# Creating card for: 聖堂
# Creating card for: 鳥羽
# Creating card for: 建国
# Creating card for: 熟す
# Creating card for: 資質
# Creating card for: 索敵
# Creating card for: 喉元
# Creating card for: 開放
# Creating card for: 言及
# Creating card for: 高々
# Creating card for: 仰る
# Creating card for: 個室
# Creating card for: 体裁
# Creating card for: 薬草
# Creating card for: 詰み
# Creating card for: 強気
# Creating card for: 他所
# Creating card for: 否々
# Creating card for: 暴走
# Creating card for: 鼻息
# Creating card for: 主君
# Creating card for: 轟音
# Creating card for: 交易
# Creating card for: 反る
# Creating card for: 望み
# Creating card for: 通路
# Creating card for: 一心
# Creating card for: 次期
# Creating card for: 結界
# Creating card for: 立身
# Creating card for: 居る
# Creating card for: 後頭
# Creating card for: 吐息
# Creating card for: 歴代
# Creating card for: 交差
# Creating card for: 醜悪
# Creating card for: 書類
# Creating card for: 重用
# Creating card for: 底辺
# Creating card for: 祝勝
# Creating card for: 持ち
# Creating card for: 適性
# Creating card for: 旨味
# Creating card for: 佐野
# Creating card for: 一流
# Creating card for: 数段
# Creating card for: 爆裂
# Creating card for: 因る
# Creating card for: 国体
# Creating card for: 纏う
# Creating card for: 分断
# Creating card for: 当分
# Creating card for: 特に
# Creating card for: 大一
# Creating card for: 五千
# Creating card for: 有る
# Creating card for: 文面
# Creating card for: 気質
# Creating card for: 接近
# Creating card for: 不敬
# Creating card for: 商家
# Creating card for: 常々
# Creating card for: 宝玉
# Creating card for: 一層
# Creating card for: 称号
# Creating card for: 書簡
# Creating card for: 靡く
# Creating card for: 直撃
# Creating card for: 益体
# Creating card for: 弱小
# Creating card for: 来客
# Creating card for: 盛ん
# Creating card for: 一室
# Creating card for: 転身
# Creating card for: 雪景
# Creating card for: 数十
# Creating card for: 静脈
# Creating card for: 運び
# Creating card for: 視界
# Creating card for: 開花
# Creating card for: 君主
# Creating card for: 人目
# Creating card for: 東方
# Creating card for: 等分
# Creating card for: 起動
# Creating card for: 声音
# Creating card for: 訪れ
# Creating card for: 自失
# Creating card for: 喧騒
# Creating card for: 賢者
# Creating card for: 破竹
# Creating card for: 内政
# Creating card for: 駐留
# Creating card for: 有無
# Creating card for: 苦言
# Creating card for: 十分
# Creating card for: 穿つ
# Creating card for: 跳び
# Creating card for: 水晶
# Creating card for: 動脈
# Creating card for: 酔狂
# Creating card for: 勇者
# Creating card for: 羊皮
# Creating card for: 強固
# Creating card for: 決別
# Creating card for: 最北
# Creating card for: 黒い
# Creating card for: 実体
# Creating card for: 格上
# Creating card for: 大使
# Creating card for: 病状
# Creating card for: 黒髪
# Creating card for: 軽々
# Creating card for: 才気
# Creating card for: 敬礼
# Creating card for: 暴発
# Creating card for: 親父
# Creating card for: 容体
# Creating card for: 沈痛
# Creating card for: 質感
# Creating card for: 魔導
# Creating card for: 名目
# Creating card for: 報せ
# Creating card for: 本国
# Creating card for: 筆頭
# Creating card for: 解体
# Creating card for: 何故
# Creating card for: 駐在
# Creating card for: 詫び
# Creating card for: 政務
# Creating card for: 口数
# Creating card for: 上程
# Creating card for: 肉食
# Creating card for: 災厄
# Creating card for: 先端
# Creating card for: 勘気
# Creating card for: 間近
# Creating card for: 両輪
# Creating card for: 深々
# Creating card for: 久々
# Creating card for: 强乱
# Creating card for: 傾倒
# Creating card for: 優等
# Creating card for: 堪る
# Creating card for: 次代
# Creating card for: 侵攻
# Creating card for: 密偵
# Creating card for: 達人
# Creating card for: 装飾
# Creating card for: 亜人
# Creating card for: 六百
# Creating card for: 人外
# Creating card for: 品位
# Creating card for: 易々
# Creating card for: 主従
# Creating card for: 風花
# Creating card for: 魔物
# Creating card for: 集う
# Creating card for: 旅人
# Creating card for: 驚異
# Creating card for: 素直
# Creating card for: 要人
# Creating card for: 為る
# Creating card for: 遣る
# Creating card for: 武官
# Creating card for: 霊薬
# Creating card for: 余る
# Creating card for: 回廊
# Creating card for: 手配
# Creating card for: 諸島
# Creating card for: 納品
# Creating card for: 二十
# Creating card for: 番う
# Creating card for: 粗野
# Creating card for: 停滞
# Creating card for: 脱退
# Creating card for: 脱力
# Creating card for: 名君
# Creating card for: 弱め
# Creating card for: 濃紺
# Creating card for: 文官
# Creating card for: 国政
# Creating card for: 満喫
# Creating card for: 右上
# Creating card for: 小川
# Creating card for: 貧国
# Creating card for: 苦い
# Creating card for: 向き
# Creating card for: 大国
# Creating card for: 付与
# Creating card for: 一角
# Creating card for: 摂政
# Creating card for: 逃す
# Creating card for: 洗練
# Creating card for: 目下
# Creating card for: 仁徳
# Creating card for: 支え
# Creating card for: 術数
# Creating card for: 嘆き
# Creating card for: 鼻面
# Creating card for: 突く
# Creating card for: 流石
# Creating card for: 豪商
# Creating card for: 恵み
# Creating card for: 意気
# Creating card for: 対処
# Creating card for: 襟元
# Creating card for: 滾つ
# Creating card for: 特等
# Creating card for: 落ち
# Creating card for: 背骨
# Creating card for: 口調
# Creating card for: 鉄板
# Creating card for: 魔力
# Creating card for: 立地
# Creating card for: 大物
# Creating card for: 決戦
# Creating card for: 一気
# Creating card for: 下限
# Creating card for: 無性
# Creating card for: 亡者
# Creating card for: 片眉
# Creating card for: 名物
# Creating card for: 物陰
# Creating card for: 相当
# Creating card for: 実害
# Creating card for: 精版
# Creating card for: 登用
# Creating card for: 助け
# Creating card for: 職探し
# Creating card for: 黄金色
# Creating card for: 為さる
# Creating card for: 言い分
# Creating card for: 総取り
# Creating card for: 縁取る
# Creating card for: 総じて
# Creating card for: 見遣る
# Creating card for: 体つき
# Creating card for: 控えめ
# Creating card for: 繋がり
# Creating card for: 同じく
# Creating card for: 揺らす
# Creating card for: 時化る
# Creating card for: 眼差し
# Creating card for: まん丸
# Creating card for: 宜しい
# Creating card for: 動ずる
# Creating card for: 召使い
# Creating card for: 見合う
# Creating card for: 着心地
# Creating card for: 涼やか
# Creating card for: 鳴らす
# Creating card for: 足取り
# Creating card for: 表わす
# Creating card for: 石造り
# Creating card for: 砕ける
# Creating card for: 賭する
# Creating card for: 手間賃
# Creating card for: 大きな
# Creating card for: 軽やか
# Creating card for: 可愛い
# Creating card for: 渦巻く
# Creating card for: 柔らか
# Creating card for: 目つき
# Creating card for: 大騒ぎ
# Creating card for: 腕組み
# Creating card for: 御座る
# Creating card for: 見越す
# Creating card for: 模する
# Creating card for: 出でる
# Creating card for: 分け前
# Creating card for: 預かる
# Creating card for: 行き来
# Creating card for: 入り口
# Creating card for: 荒らす
# Creating card for: 見下す
# Creating card for: 煩わす
# Creating card for: 傾げる
# Creating card for: 出来事
# Creating card for: 華やぐ
# Creating card for: 案ずる
# Creating card for: 幼馴染
# Creating card for: この世
# Creating card for: 王太子
# Creating card for: 発する
# Creating card for: 身なり
# Creating card for: 木っ端
# Creating card for: 存ずる
# Creating card for: 食する
# Creating card for: 繋がる
# Creating card for: 板挟み
# Creating card for: 切れる
# Creating card for: 奥まる
# Creating card for: 助かる
# Creating card for: 顔立ち
# Creating card for: 羽織る
# Creating card for: 差さる
# Creating card for: १०१
# Creating card for: また上
# Creating card for: 間違い
# Creating card for: 悔やむ
# Creating card for: 違える
# Creating card for: 今日は
# Creating card for: ･･･
# Creating card for: 削れる
# Creating card for: 御早う
# Creating card for: 見向く
# Creating card for: 温かい
# Creating card for: 信ずる
# Creating card for: 哀れみ
# Creating card for: 指折り
# Creating card for: 六本木
# Creating card for: 気取り
# Creating card for: 見開く
# Creating card for: 剥がす
# Creating card for: 振るう
# Creating card for: 押し開く
# Creating card for: かじ取り
# Creating card for: 面食らう
# Creating card for: 思いの外
# Creating card for: 向こう側
# Creating card for: こちら側
# Creating card for: 目覚まし
# Creating card for: 押し出す
# Creating card for: 辿り着く
# Creating card for: そう伝聞
# Creating card for: 駆け寄る
# Creating card for: ････
# Creating card for: 取り残す
# Creating card for: 人となり
# Creating card for: 初々しい
# Creating card for: 小間使い
# Creating card for: 素知らぬ
# Creating card for: 問いかけ
# Creating card for: 耳慣れる
# Creating card for: 差し出す
# Creating card for: 聞き返す
# Creating card for: 立ち読み
# Creating card for: 聞き取る
# Creating card for: 歯ぎしり
# Creating card for: 相応しい
# Creating card for: 申しわけ
# Creating card for: 食い入る
# Creating card for: 思い切る
# Creating card for: 突っ伏す
# Creating card for: 出で立ち
# Creating card for: むき出し
# Creating card for: 締め直す
# Creating card for: 引き渡す
# Creating card for: 腰掛ける
# Creating card for: 飛び込む
# Creating card for: 貸し切る
# Creating card for: 話し合い
# Creating card for: 乗り切る
# Creating card for: 言葉遣い
# Creating card for: 有り難い
# Creating card for: 見透かす
# Creating card for: 消し飛ぶ
# Creating card for: 付き添う
# Creating card for: 赤茶ける
# Creating card for: 有り難う
# Creating card for: 突き出す
# Creating card for: 見付かる
# Creating card for: 受け取り
# Creating card for: 突き返す
# Creating card for: 請け負う
# Creating card for: 置き去り
# Creating card for: 然う然う
# Creating card for: 走り去る
# Creating card for: 清々しい
# Creating card for: 言い切る
# Creating card for: 押し込む
# Creating card for: 持ち帰る
# Creating card for: 冷やかし
# Creating card for: 今しがた
# Creating card for: 入り込む
# Creating card for: 仕方無い
# Creating card for: 頷き合う
# Creating card for: 覗き込む
# Creating card for: 吹き抜け
# Creating card for: 抱き付く
# Creating card for: そう様態
# Creating card for: 見据える
# Creating card for: 張り出す
# Creating card for: 手掛ける
# Creating card for: なり断定
# Creating card for: 見付ける
# Creating card for: 変わり者
# Creating card for: 起き上がる
# Creating card for: 吹き上げる
# Creating card for: 話し掛ける
# Creating card for: 思いっきり
# Creating card for: 執り行なう
# Creating card for: 取り掛かる
# Creating card for: 舞い上がる
# Creating card for: 叩きのめす
# Creating card for: 憎たらしい
# Creating card for: 差し掛かる
# Creating card for: 立ち込める
# Creating card for: だらし無い
# Creating card for: 突き付ける
# Creating card for: 問い掛ける
# Creating card for: 踏み付ける
# Creating card for: 転げ落ちる
# Creating card for: 待ちぼうけ
# Creating card for: 呼び掛ける
# Creating card for: 締めくくり
# Creating card for: 立ち上げる
# Creating card for: 込み上げる
# Creating card for: 突っ撥ねる
# Creating card for: 敷き詰める
# Creating card for: 落ちこぼれ
# Creating card for: 混ざり合う
# Creating card for: 撥ね除ける
# Creating card for: 入れ替わる
# Creating card for: 吊り下がる
# Creating card for: 田舎暮らし
# Creating card for: 突き詰める
# Creating card for: 打ち明ける
# Creating card for: 突き当たり
# Creating card for: 消え失せる
# Creating card for: 書き下ろし
# Creating card for: 蹴り飛ばす
# Creating card for: 世迷いごと
# Creating card for: 打っ飛ばす
# Creating card for: 染め上げる
# Creating card for: 浮かび上がる
# Creating card for: ･･････
# 292 55
# CPU times: total: 141 ms
# Wall time: 2.29 s

# %% [markdown]
# get card ids:
#
# 2.1s per search ==> <3s for 500 checks

# %%
# %%time
subset = words
# "deck:nhg::3vocab Word:木 OR Word:気"
# -> this is a valid one
wordstrs = ["".join(f"Word:{word}") for word in subset]
query = "deck:nhg::3vocab " + " OR ".join(wordstrs)
print(len(query), query)
card_ids = get_word_card_ids(query)
# card_ids = [get_word_card_id(word) for word in subset]
card_ids
# 10 words -> ~21s
# ~2.1s per search -> 500 cards would be ~18min
# collection().find_cards
# new method: ->
# Out:
# 6656 deck:nhg::3vocab Word:予 OR Word:伸 OR Word:称 OR Word:刷 OR Word:是 OR Word:= OR Word:読 OR Word:€ OR Word:負 OR Word:語 OR Word:徹 OR Word:◆ OR Word:立 OR Word:異 OR Word:☑ OR Word:助 OR Word:回 OR Word:当 OR Word:后 OR Word:観 OR Word:臨 OR Word:+ OR Word:･ OR Word:◇ OR Word:吹 OR Word:装 OR Word:〜 OR Word:© OR Word:再 OR Word:問 OR Word:嬢 OR Word:× OR Word:片 OR Word:素 OR Word:近 OR Word:室 OR Word:書 OR Word:館 OR Word:屋 OR Word:座 OR Word:聖 OR Word:栄 OR Word:童 OR Word:· OR Word:礫 OR Word:誉 OR Word:秀 OR Word:第 OR Word:腐 OR Word:超 OR Word:識 OR Word:% OR Word:師 OR Word:判 OR Word:官 OR Word:礼 OR Word:感 OR Word:― OR Word:優 OR Word:我 OR Word:丁 OR Word:延 OR Word:詬 OR Word:最 OR Word:頃 OR Word:Ő OR Word:譲 OR Word:貸 OR Word:隷 OR Word:職 OR Word:୪ OR Word:関 OR Word:肢 OR Word:定 OR Word:☐ OR Word:← OR Word:ㄖ OR Word:峰 OR Word:未 OR Word:少 OR Word:起 OR Word:代 OR Word:傍 OR Word:陣 OR Word:側 OR Word:全 OR Word:化 OR Word:並 OR Word:同 OR Word:✓ OR Word:業火 OR Word:悪鬼 OR Word:金貨 OR Word:転機 OR Word:素質 OR Word:ラ王 OR Word:要求 OR Word:一定 OR Word:契機 OR Word:造詣 OR Word:転送 OR Word:筋力 OR Word:製本 OR Word:近々 OR Word:不毛 OR Word:北端 OR Word:過労 OR Word:軍部 OR Word:実地 OR Word:火種 OR Word:随一 OR Word:ㄈㄨ OR Word:商業 OR Word:家臣 OR Word:真っ OR Word:無い OR Word:意地 OR Word:新規 OR Word:旨い OR Word:十全 OR Word:合本 OR Word:全土 OR Word:教導 OR Word:見目 OR Word:感服 OR Word:暗転 OR Word:権謀 OR Word:執務 OR Word:調達 OR Word:嫌み OR Word:過ぎ OR Word:売国 OR Word:呻く OR Word:奇異 OR Word:裁定 OR Word:山脈 OR Word:広々 OR Word:体質 OR Word:何に OR Word:自適 OR Word:奮起 OR Word:来訪 OR Word:半ば OR Word:造り OR Word:五十 OR Word:遠目 OR Word:賢君 OR Word:政争 OR Word:中庭 OR Word:生来 OR Word:真似 OR Word:占領 OR Word:聖堂 OR Word:鳥羽 OR Word:建国 OR Word:熟す OR Word:資質 OR Word:索敵 OR Word:喉元 OR Word:開放 OR Word:言及 OR Word:高々 OR Word:仰る OR Word:個室 OR Word:体裁 OR Word:薬草 OR Word:詰み OR Word:強気 OR Word:他所 OR Word:否々 OR Word:暴走 OR Word:鼻息 OR Word:主君 OR Word:轟音 OR Word:交易 OR Word:反る OR Word:望み OR Word:通路 OR Word:一心 OR Word:次期 OR Word:結界 OR Word:立身 OR Word:居る OR Word:後頭 OR Word:吐息 OR Word:歴代 OR Word:交差 OR Word:醜悪 OR Word:書類 OR Word:重用 OR Word:底辺 OR Word:祝勝 OR Word:持ち OR Word:適性 OR Word:旨味 OR Word:佐野 OR Word:一流 OR Word:数段 OR Word:爆裂 OR Word:因る OR Word:国体 OR Word:纏う OR Word:分断 OR Word:当分 OR Word:特に OR Word:大一 OR Word:五千 OR Word:有る OR Word:文面 OR Word:気質 OR Word:接近 OR Word:不敬 OR Word:商家 OR Word:常々 OR Word:宝玉 OR Word:一層 OR Word:称号 OR Word:書簡 OR Word:靡く OR Word:直撃 OR Word:益体 OR Word:弱小 OR Word:来客 OR Word:盛ん OR Word:一室 OR Word:転身 OR Word:雪景 OR Word:数十 OR Word:静脈 OR Word:運び OR Word:視界 OR Word:開花 OR Word:君主 OR Word:人目 OR Word:東方 OR Word:等分 OR Word:起動 OR Word:声音 OR Word:訪れ OR Word:自失 OR Word:喧騒 OR Word:賢者 OR Word:破竹 OR Word:内政 OR Word:駐留 OR Word:有無 OR Word:苦言 OR Word:十分 OR Word:穿つ OR Word:跳び OR Word:水晶 OR Word:動脈 OR Word:酔狂 OR Word:勇者 OR Word:羊皮 OR Word:強固 OR Word:決別 OR Word:最北 OR Word:黒い OR Word:実体 OR Word:格上 OR Word:大使 OR Word:病状 OR Word:黒髪 OR Word:軽々 OR Word:才気 OR Word:敬礼 OR Word:暴発 OR Word:親父 OR Word:容体 OR Word:沈痛 OR Word:質感 OR Word:魔導 OR Word:名目 OR Word:報せ OR Word:本国 OR Word:筆頭 OR Word:解体 OR Word:何故 OR Word:駐在 OR Word:詫び OR Word:政務 OR Word:口数 OR Word:上程 OR Word:肉食 OR Word:災厄 OR Word:先端 OR Word:勘気 OR Word:間近 OR Word:両輪 OR Word:深々 OR Word:久々 OR Word:强乱 OR Word:傾倒 OR Word:優等 OR Word:堪る OR Word:次代 OR Word:侵攻 OR Word:密偵 OR Word:達人 OR Word:装飾 OR Word:亜人 OR Word:六百 OR Word:人外 OR Word:品位 OR Word:易々 OR Word:主従 OR Word:風花 OR Word:魔物 OR Word:集う OR Word:旅人 OR Word:驚異 OR Word:素直 OR Word:要人 OR Word:為る OR Word:遣る OR Word:武官 OR Word:霊薬 OR Word:余る OR Word:回廊 OR Word:手配 OR Word:諸島 OR Word:納品 OR Word:二十 OR Word:番う OR Word:粗野 OR Word:停滞 OR Word:脱退 OR Word:脱力 OR Word:名君 OR Word:弱め OR Word:濃紺 OR Word:文官 OR Word:国政 OR Word:満喫 OR Word:右上 OR Word:小川 OR Word:貧国 OR Word:苦い OR Word:向き OR Word:大国 OR Word:付与 OR Word:一角 OR Word:摂政 OR Word:逃す OR Word:洗練 OR Word:目下 OR Word:仁徳 OR Word:支え OR Word:術数 OR Word:嘆き OR Word:鼻面 OR Word:突く OR Word:流石 OR Word:豪商 OR Word:恵み OR Word:意気 OR Word:対処 OR Word:襟元 OR Word:滾つ OR Word:特等 OR Word:落ち OR Word:背骨 OR Word:口調 OR Word:鉄板 OR Word:魔力 OR Word:立地 OR Word:大物 OR Word:決戦 OR Word:一気 O ...
# CPU times: total: 0 ns
# Wall time: 2.79 s
# [1452224257092,
#  1452224257602,
#  1452224257966,
#  1452224258132,
#  1452224258610,
#  1452224258672,
#  1452224258696,
#  1452224258702,
#  1452224259022,
#  1452224259860,
#  1452224260154,
#  1452224261436,
#  1452224261510,
#  1452224261630,
#  1452224261946,
#  1452224261994,
#  1452224262000,
#  1452224262004,
#  1452224262142,
#  1452224262398,
#  1452224262544,
#  1452224262884,
#  1452224263308,
#  1452224263590,
#  1452224263746,
#  1452224263800,
#  1452224263840,
#  1452224263938,
#  1452224263950,
#  1452224264788,
#  1452224265220,
#  1452224265550,
#  1452224265634,
#  1452224265868,
#  1452224266160,
#  1452224266258,
#  1452224266408,
#  1452224266420,
#  1452224266632,
#  1452224266782,
#  1452224266874,
#  1452224266887,
#  1452224266999,
#  1452224267050,
#  1452224267070,
#  1452224267122,
#  1452224267131,
#  1452224267132,
#  1452224267155,
#  1452224267189,
#  1452224267244,
#  1452224267385,
#  1452224267460,
#  1452224267633,
#  1452224267661,
#  1452224267773,
#  1452224267950,
#  1452224267977,
#  1452224268040,
#  1452224268072,
#  1452224268235,
#  1452224268695,
#  1452224268702,
#  1452224268729,
#  1452224268776,
#  1452224268875,
#  1452224268888,
#  1452224268934,
#  1452224268959,
#  1452224269078,
#  1452224269083,
#  1452224269143,
#  1452224269381,
#  1452224269414,
#  1452224269464,
#  1452224269490,
#  1452224269508,
#  1452224269509,
#  1452224269839,
#  1452224270135,
#  1452224270345,
#  1452224270468,
#  1452224279161,
#  1452224279195,
#  1452224279317,
#  1452224279381,
#  1452224279603,
#  1452224279739,
#  1452224280533,
#  1452224280629,
#  1452224281191,
#  1452224281307,
#  1452224281981,
#  1452224282185,
#  1452224282191,
#  1452224282213,
#  1452224282437,
#  1452224282571,
#  1452224282573,
#  1452224282683,
#  1452224282787,
#  1452224282925,
#  1452224283081,
#  1452224283087,
#  1452224283091,
#  1452224283235,
#  1452224283513,
#  1452224284037,
#  1452224284043,
#  1452224284303,
#  1452224284447,
#  1452224285101,
#  1452224285159,
#  1452224285303,
#  1452224285549,
#  1452224285555,
#  1452224285805,
#  1452224286163,
#  1452224286179,
#  1452224286605,
#  1452224286959,
#  1452224287241,
#  1452224287273,
#  1452224287739,
#  1452224287793,
#  1452224287935,
#  1452224288113,
#  1452224288161,
#  1452224288203,
#  1452224288733,
#  1452224288787,
#  1452224288789,
#  1452224289169,
#  1452224289493,
#  1452224289651,
#  1452224289727,
#  1452224289975,
#  1452224290147,
#  1452224290153,
#  1452224290265,
#  1452224290651,
#  1452224290997,
#  1452224291403,
#  1452224291639,
#  1452224291767,
#  1452224292435,
#  1452224292453,
#  1452224292495,
#  1452224292703,
#  1452224292733,
#  1452224292935,
#  1452224293019,
#  1452224293025,
#  1452224293435,
#  1452224293705,
#  1452224294457,
#  1452224294527,
#  1452224294729,
#  1452224294801,
#  1452224295019,
#  1452224295472,
#  1452224295717,
#  1452224295815,
#  1452224295910,
#  1452224296772,
#  1452224296840,
#  1452224296982,
#  1452224297020,
#  1452224297120,
#  1452224297149,
#  1452224297393,
#  1452224297399,
#  1452224297839,
#  1532108090613,
#  1532108092267,
#  1532108092505,
#  1539620046812,
#  1733984459406,
#  1733984459407,
#  1733984459408,
#  1733984459409,
#  1733984459410,
#  1733984459411,
#  1733984459412,
#  1733984459413,
#  1733984459414,
#  1733984459415,
#  1733984459416,
#  1733984459417,
#  1733984459418,
#  1733984459419,
#  1733984459420,
#  1733984459421,
#  1733984459422,
#  1733984459423,
#  1733984459424,
#  1733984459425,
#  1733984459426,
#  1733984459427,
#  1733984459428,
#  1733984459429,
#  1733984459430,
#  1733984459431,
#  1733984459432,
#  1733984459433,
#  1733984459434,
#  1733984459435,
#  1733984459436,
#  1733984459437,
#  1733984459438,
#  1733984459439,
#  1733984459440,
#  1733984459441,
#  1733984459442,
#  1733984459443,
#  1733984459444,
#  1733984459445,
#  1733984459446,
#  1733984459447,
#  1733984459448,
#  1733984459449,
#  1733984459450,
#  1733984459451,
#  1733984459452,
#  1733984459453,
#  1733984459454,
#  1733984459455,
#  1733984459456,
#  1733984459457,
#  1733984459458,
#  1733984459459,
#  1733984459460,
#  1733984459461,
#  1733984459462,
#  1733984682335,
#  1733984682336,
#  1733984682337,
#  1733984682338,
#  1733984682339,
#  1733984682340,
#  1733984682341,
#  1733984682342,
#  1733984682343,
#  1733984682344,
#  1733984682345,
#  1733984682346,
#  1733984682347,
#  1733984682348,
#  1733984682349,
#  1733984682350,
#  1733984682351,
#  1733984682352,
#  1733984682353,
#  1733984682354,
#  1733984682355,
#  1733984682356,
#  1733984682357,
#  1733984682358,
#  1733984682359,
#  1733984682360,
#  1733984682361,
#  1733984682362,
#  1733984682363,
#  1733984682364,
#  1733984682365,
#  1733984682366,
#  1733984682367,
#  1733984682368,
#  1733984682369,
#  1733984682370,
#  1733984682371,
#  1733984682372,
#  1733984682373,
#  1733984682374,
#  1733984682375,
#  1733984682376,
#  1733984682377,
#  1733984682378,
#  1733984682379,
#  1733984682380,
#  1733984682381,
#  1733984682382,
#  1733984682383,
#  1733984682384,
#  1733984682385,
#  1733984682386,
#  1733984682387,
#  1733984682388,
#  1733984682389,
#  1733984682390,
#  1733984682391,
#  1733984682392,
#  1733984682393,
#  1733984682394,
#  1733984682395,
#  1733984682396,
#  1733984682397,
#  1733984682398,
#  1733984682399,
#  1733984682400,
#  1733984682401,
#  1733984682402,
#  1733984682403,
#  1733984682404,
#  1733984682405,
#  1733984682406,
#  1733984682407,
#  1733984682408,
#  1733984682409,
#  1733984682410,
#  1733984682411,
#  1733984682412,
#  1733984682413,
#  1733984682414,
#  1733984682415,
#  1733984682416,
#  1733984682417,
#  1733984682418,
#  1733984682419,
#  1733984682420,
#  1733984682421,
#  1733984682422,
#  1733984682423,
#  1733984682424,
#  1733984682425,
#  1733984682426,
#  1733984682427,
#  1733984682428,
#  1733984682429,
#  1733984682430,
#  1733984682431,
#  1733984682432,
#  1733984682433,
#  1733984682434,
#  1733984682435,
#  1733984682436,
#  1733984682437,
#  1733984682438,
#  1733984682439,
#  1733984682440,
#  1733984682441,
#  1733984682442,
#  1733984682443,
#  1733984682444,
#  1733984682445,
#  1733984682446,
#  1733984682447,
#  1733984682448,
#  1733984682449,
#  1733984682450,
#  1733984682451,
#  1733984682452,
#  1733984682453,
#  1733984682454,
#  1733984682455,
#  1733984682456,
#  1733984682457,
#  1733984682458,
#  1733984682459,
#  1733984682460,
#  1733984682461,
#  1733984682462,
#  1733984682463,
#  1733984682464,
#  1733984682465,
#  1733984682466,
#  1733984682467,
#  1733984682468,
#  1733984682469,
#  1733984682470,
#  1733984682471,
#  1733984682472,
#  1733984682473,
#  1733984682474,
#  1733984682475,
#  1733984682476,
#  1733984682477,
#  1733984682478,
#  1733984682479,
#  1733984682480,
#  1733984682481,
#  1733984682482,
#  1733984682483,
#  1733984682484,
#  1733984682485,
#  1733984682486,
#  1733984682487,
#  1733984682488,
#  1733984682489,
#  1733984682490,
#  1733984682491,
#  1733984682492,
#  1733984682493,
#  1733984682494,
#  1733984682495,
#  1733984682496,
#  1733984682497,
#  1733984682498,
#  1733984682499,
#  1733984682500,
#  1733984682501,
#  1733984682502,
#  1733984682503,
#  1733984682504,
#  1733984682505,
#  1733984682506,
#  1733984682507,
#  1733984682508,
#  1733984682509,
#  1733984682510,
#  1733984682511,
#  1733984682512,
#  1733984682513,
#  1733984682514,
#  1733984682515,
#  1733984682516,
#  1733984682517,
#  1733984682518,
#  1733984682519,
#  1733984682520,
#  1733984682521,
#  1733984682522,
#  1733984682523,
#  1733984682524,
#  1733984682525,
#  1733984682526,
#  1733984682527,
#  1733984682528,
#  1733984682529,
#  1733984682530,
#  1733984682531,
#  1733984682532,
#  1733984682533,
#  1733984682534,
#  1733984682535,
#  1733984682536,
#  1733984682537,
#  1733984682538,
#  1733984682539,
#  1733984682540,
#  1733984682541,
#  1733984682542,
#  1733984682543,
#  1733984682544,
#  1733984682545,
#  1733984682546,
#  1733984682547,
#  1733984682548,
#  1733984682549,
#  1733984682550,
#  1733984682551,
#  1733984682552,
#  1733984682553,
#  1733984682554,
#  1733984682555,
#  1733984682556,
#  1733984682557,
#  1733984682558,
#  1733984682559,
#  1733984682560,
#  1733984682561,
#  1733984682562,
#  1733984682563,
#  1733984682564,
#  1733984682565,
#  1733984682566,
#  1733984682567,
#  1733984682568,
#  1733984682569,
#  1733984682570,
#  1733984682571,
#  1733984682572,
#  1733984682573,
#  1733984682574,
#  1733984682575,
#  1733984682576,
#  1733984682577,
#  1733984682578,
#  1733984682579,
#  1733984682580,
#  1733984682581,
#  1733984682582,
#  1733984682583,
#  1733984682584,
#  1733984682585,
#  1733984682586,
#  1733984682587,
#  1733984682588,
#  1733984682589,
#  1733984682590,
#  1733984682591,
#  1733984682592,
#  1733984682593,
#  1733984682594,
#  1733984682595,
#  1733984682596,
#  1733984682597,
#  1733984682598,
#  1733984682599,
#  1733984682600,
#  1733984682601,
#  1733984682602,
#  1733984682603,
#  1733984682604,
#  1733984682605,
#  1733984682606,
#  1733984682607,
#  1733984682608,
#  1733984682609,
#  1733984682610,
#  1733984682611,
#  1733984682612,
#  1733984682613,
#  1733984682614,
#  1733984682615,
#  1733984682616,
#  1733984682617,
#  1733984682618,
#  1733984682619,
#  1733984682620,
#  1733984682621,
#  1733984682622,
#  1733984682623,
#  1733984682624,
#  1733984682625,
#  1733984682626]

# %% [markdown]
# schedule() -> literally only a few seconds
#
# - 525 words (newly scheduled) -> less than 5s
# - 525 words (skipped) -> less than 5s

# %%
# %%time
len(card_ids)
# results, key_error, skipped = schedule(card_ids, 1)
results, len(key_error), len(skipped)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# (datetime.date(2024, 12, 12), 0, 525)

# %% [markdown]
# - 580 words, 349 notes created, 55 not found, scheduled 525
# - CPU times: total: 312 ms
# - Wall time: 9.74 s
#
# rerun for idempotency:
# - CPU times: total: 109 ms
# - Wall time: 9.34 s

# %%
# %%time
#matomeru:

words = easy
print(len(words))
results, not_found = create_notes(words, skip_checks=False)
print("Create notes results: ", results, len(not_found))

subset = words
wordstrs = ["".join(f"Word:{word}") for word in subset]
query = "deck:nhg::3vocab " + " OR ".join(wordstrs)
print(len(query), query)
card_ids = get_word_card_ids(query)
print("Cards found: ", len(card_ids))

results, key_error, skipped = schedule(card_ids, 1)
results, len(key_error), len(skipped)
# Out:
# 580
# Creating card for: 予
# Creating card for: 伸
# Creating card for: 称
# Creating card for: 刷
# Creating card for: 是
# Creating card for: =
# Creating card for: 読
# Creating card for: €
# Creating card for: 負
# Creating card for: 語
# Creating card for: 徹
# Creating card for: ◆
# Creating card for: 立
# Creating card for: 異
# Creating card for: ☑
# Creating card for: 助
# Creating card for: 回
# Creating card for: 当
# Creating card for: 后
# Creating card for: 観
# Creating card for: 臨
# Creating card for: +
# Creating card for: ･
# Creating card for: ◇
# Creating card for: 吹
# Creating card for: 装
# Creating card for: 〜
# Creating card for: ©
# Creating card for: 再
# Creating card for: 問
# Creating card for: 嬢
# Creating card for: ×
# Creating card for: 片
# Creating card for: 素
# Creating card for: 近
# Creating card for: 室
# Creating card for: 書
# Creating card for: 館
# Creating card for: 屋
# Creating card for: 座
# Creating card for: 聖
# Creating card for: 栄
# Creating card for: 童
# Creating card for: ·
# Creating card for: 礫
# Creating card for: 誉
# Creating card for: 秀
# Creating card for: 第
# Creating card for: 腐
# Creating card for: 超
# Creating card for: 識
# Creating card for: %
# Creating card for: 師
# Creating card for: 判
# Creating card for: 官
# Creating card for: 礼
# Creating card for: 感
# Creating card for: ―
# Creating card for: 優
# Creating card for: 我
# Creating card for: 丁
# Creating card for: 延
# Creating card for: 詬
# Creating card for: 最
# Creating card for: 頃
# Creating card for: Ő
# Creating card for: 譲
# Creating card for: 貸
# Creating card for: 隷
# Creating card for: 職
# Creating card for: ୪
# Creating card for: 関
# Creating card for: 肢
# Creating card for: 定
# Creating card for: ☐
# Creating card for: ←
# Creating card for: ㄖ
# Creating card for: 峰
# Creating card for: 未
# Creating card for: 少
# Creating card for: 起
# Creating card for: 代
# Creating card for: 傍
# Creating card for: 陣
# Creating card for: 側
# Creating card for: 全
# Creating card for: 化
# Creating card for: 並
# Creating card for: 同
# Creating card for: ✓
# Creating card for: 業火
# Creating card for: 悪鬼
# Creating card for: 金貨
# Creating card for: 転機
# Creating card for: 素質
# Creating card for: ラ王
# Creating card for: 要求
# Creating card for: 一定
# Creating card for: 契機
# Creating card for: 造詣
# Creating card for: 転送
# Creating card for: 筋力
# Creating card for: 製本
# Creating card for: 近々
# Creating card for: 不毛
# Creating card for: 北端
# Creating card for: 過労
# Creating card for: 軍部
# Creating card for: 実地
# Creating card for: 火種
# Creating card for: 随一
# Creating card for: ㄈㄨ
# Creating card for: 商業
# Creating card for: 家臣
# Creating card for: 真っ
# Creating card for: 無い
# Creating card for: 意地
# Creating card for: 新規
# Creating card for: 旨い
# Creating card for: 十全
# Creating card for: 合本
# Creating card for: 全土
# Creating card for: 教導
# Creating card for: 見目
# Creating card for: 感服
# Creating card for: 暗転
# Creating card for: 権謀
# Creating card for: 執務
# Creating card for: 調達
# Creating card for: 嫌み
# Creating card for: 過ぎ
# Creating card for: 売国
# Creating card for: 呻く
# Creating card for: 奇異
# Creating card for: 裁定
# Creating card for: 山脈
# Creating card for: 広々
# Creating card for: 体質
# Creating card for: 何に
# Creating card for: 自適
# Creating card for: 奮起
# Creating card for: 来訪
# Creating card for: 半ば
# Creating card for: 造り
# Creating card for: 五十
# Creating card for: 遠目
# Creating card for: 賢君
# Creating card for: 政争
# Creating card for: 中庭
# Creating card for: 生来
# Creating card for: 真似
# Creating card for: 占領
# Creating card for: 聖堂
# Creating card for: 鳥羽
# Creating card for: 建国
# Creating card for: 熟す
# Creating card for: 資質
# Creating card for: 索敵
# Creating card for: 喉元
# Creating card for: 開放
# Creating card for: 言及
# Creating card for: 高々
# Creating card for: 仰る
# Creating card for: 個室
# Creating card for: 体裁
# Creating card for: 薬草
# Creating card for: 詰み
# Creating card for: 強気
# Creating card for: 他所
# Creating card for: 否々
# Creating card for: 暴走
# Creating card for: 鼻息
# Creating card for: 主君
# Creating card for: 轟音
# Creating card for: 交易
# Creating card for: 反る
# Creating card for: 望み
# Creating card for: 通路
# Creating card for: 一心
# Creating card for: 次期
# Creating card for: 結界
# Creating card for: 立身
# Creating card for: 居る
# Creating card for: 後頭
# Creating card for: 吐息
# Creating card for: 歴代
# Creating card for: 交差
# Creating card for: 醜悪
# Creating card for: 書類
# Creating card for: 重用
# Creating card for: 底辺
# Creating card for: 祝勝
# Creating card for: 持ち
# Creating card for: 適性
# Creating card for: 旨味
# Creating card for: 佐野
# Creating card for: 一流
# Creating card for: 数段
# Creating card for: 爆裂
# Creating card for: 因る
# Creating card for: 国体
# Creating card for: 纏う
# Creating card for: 分断
# Creating card for: 当分
# Creating card for: 特に
# Creating card for: 大一
# Creating card for: 五千
# Creating card for: 有る
# Creating card for: 文面
# Creating card for: 気質
# Creating card for: 接近
# Creating card for: 不敬
# Creating card for: 商家
# Creating card for: 常々
# Creating card for: 宝玉
# Creating card for: 一層
# Creating card for: 称号
# Creating card for: 書簡
# Creating card for: 靡く
# Creating card for: 直撃
# Creating card for: 益体
# Creating card for: 弱小
# Creating card for: 来客
# Creating card for: 盛ん
# Creating card for: 一室
# Creating card for: 転身
# Creating card for: 雪景
# Creating card for: 数十
# Creating card for: 静脈
# Creating card for: 運び
# Creating card for: 視界
# Creating card for: 開花
# Creating card for: 君主
# Creating card for: 人目
# Creating card for: 東方
# Creating card for: 等分
# Creating card for: 起動
# Creating card for: 声音
# Creating card for: 訪れ
# Creating card for: 自失
# Creating card for: 喧騒
# Creating card for: 賢者
# Creating card for: 破竹
# Creating card for: 内政
# Creating card for: 駐留
# Creating card for: 有無
# Creating card for: 苦言
# Creating card for: 十分
# Creating card for: 穿つ
# Creating card for: 跳び
# Creating card for: 水晶
# Creating card for: 動脈
# Creating card for: 酔狂
# Creating card for: 勇者
# Creating card for: 羊皮
# Creating card for: 強固
# Creating card for: 決別
# Creating card for: 最北
# Creating card for: 黒い
# Creating card for: 実体
# Creating card for: 格上
# Creating card for: 大使
# Creating card for: 病状
# Creating card for: 黒髪
# Creating card for: 軽々
# Creating card for: 才気
# Creating card for: 敬礼
# Creating card for: 暴発
# Creating card for: 親父
# Creating card for: 容体
# Creating card for: 沈痛
# Creating card for: 質感
# Creating card for: 魔導
# Creating card for: 名目
# Creating card for: 報せ
# Creating card for: 本国
# Creating card for: 筆頭
# Creating card for: 解体
# Creating card for: 何故
# Creating card for: 駐在
# Creating card for: 詫び
# Creating card for: 政務
# Creating card for: 口数
# Creating card for: 上程
# Creating card for: 肉食
# Creating card for: 災厄
# Creating card for: 先端
# Creating card for: 勘気
# Creating card for: 間近
# Creating card for: 両輪
# Creating card for: 深々
# Creating card for: 久々
# Creating card for: 强乱
# Creating card for: 傾倒
# Creating card for: 優等
# Creating card for: 堪る
# Creating card for: 次代
# Creating card for: 侵攻
# Creating card for: 密偵
# Creating card for: 達人
# Creating card for: 装飾
# Creating card for: 亜人
# Creating card for: 六百
# Creating card for: 人外
# Creating card for: 品位
# Creating card for: 易々
# Creating card for: 主従
# Creating card for: 風花
# Creating card for: 魔物
# Creating card for: 集う
# Creating card for: 旅人
# Creating card for: 驚異
# Creating card for: 素直
# Creating card for: 要人
# Creating card for: 為る
# Creating card for: 遣る
# Creating card for: 武官
# Creating card for: 霊薬
# Creating card for: 余る
# Creating card for: 回廊
# Creating card for: 手配
# Creating card for: 諸島
# Creating card for: 納品
# Creating card for: 二十
# Creating card for: 番う
# Creating card for: 粗野
# Creating card for: 停滞
# Creating card for: 脱退
# Creating card for: 脱力
# Creating card for: 名君
# Creating card for: 弱め
# Creating card for: 濃紺
# Creating card for: 文官
# Creating card for: 国政
# Creating card for: 満喫
# Creating card for: 右上
# Creating card for: 小川
# Creating card for: 貧国
# Creating card for: 苦い
# Creating card for: 向き
# Creating card for: 大国
# Creating card for: 付与
# Creating card for: 一角
# Creating card for: 摂政
# Creating card for: 逃す
# Creating card for: 洗練
# Creating card for: 目下
# Creating card for: 仁徳
# Creating card for: 支え
# Creating card for: 術数
# Creating card for: 嘆き
# Creating card for: 鼻面
# Creating card for: 突く
# Creating card for: 流石
# Creating card for: 豪商
# Creating card for: 恵み
# Creating card for: 意気
# Creating card for: 対処
# Creating card for: 襟元
# Creating card for: 滾つ
# Creating card for: 特等
# Creating card for: 落ち
# Creating card for: 背骨
# Creating card for: 口調
# Creating card for: 鉄板
# Creating card for: 魔力
# Creating card for: 立地
# Creating card for: 大物
# Creating card for: 決戦
# Creating card for: 一気
# Creating card for: 下限
# Creating card for: 無性
# Creating card for: 亡者
# Creating card for: 片眉
# Creating card for: 名物
# Creating card for: 物陰
# Creating card for: 相当
# Creating card for: 実害
# Creating card for: 精版
# Creating card for: 登用
# Creating card for: 助け
# Creating card for: 職探し
# Creating card for: 黄金色
# Creating card for: 為さる
# Creating card for: 言い分
# Creating card for: 総取り
# Creating card for: 縁取る
# Creating card for: 総じて
# Creating card for: 見遣る
# Creating card for: 体つき
# Creating card for: 控えめ
# Creating card for: 繋がり
# Creating card for: 同じく
# Creating card for: 揺らす
# Creating card for: 時化る
# Creating card for: 眼差し
# Creating card for: まん丸
# Creating card for: 宜しい
# Creating card for: 動ずる
# Creating card for: 召使い
# Creating card for: 見合う
# Creating card for: 着心地
# Creating card for: 涼やか
# Creating card for: 鳴らす
# Creating card for: 足取り
# Creating card for: 表わす
# Creating card for: 石造り
# Creating card for: 砕ける
# Creating card for: 賭する
# Creating card for: 手間賃
# Creating card for: 大きな
# Creating card for: 軽やか
# Creating card for: 可愛い
# Creating card for: 渦巻く
# Creating card for: 柔らか
# Creating card for: 目つき
# Creating card for: 大騒ぎ
# Creating card for: 腕組み
# Creating card for: 御座る
# Creating card for: 見越す
# Creating card for: 模する
# Creating card for: 出でる
# Creating card for: 分け前
# Creating card for: 預かる
# Creating card for: 行き来
# Creating card for: 入り口
# Creating card for: 荒らす
# Creating card for: 見下す
# Creating card for: 煩わす
# Creating card for: 傾げる
# Creating card for: 出来事
# Creating card for: 華やぐ
# Creating card for: 案ずる
# Creating card for: 幼馴染
# Creating card for: この世
# Creating card for: 王太子
# Creating card for: 発する
# Creating card for: 身なり
# Creating card for: 木っ端
# Creating card for: 存ずる
# Creating card for: 食する
# Creating card for: 繋がる
# Creating card for: 板挟み
# Creating card for: 切れる
# Creating card for: 奥まる
# Creating card for: 助かる
# Creating card for: 顔立ち
# Creating card for: 羽織る
# Creating card for: 差さる
# Creating card for: १०१
# Creating card for: また上
# Creating card for: 間違い
# Creating card for: 悔やむ
# Creating card for: 違える
# Creating card for: 今日は
# Creating card for: ･･･
# Creating card for: 削れる
# Creating card for: 御早う
# Creating card for: 見向く
# Creating card for: 温かい
# Creating card for: 信ずる
# Creating card for: 哀れみ
# Creating card for: 指折り
# Creating card for: 六本木
# Creating card for: 気取り
# Creating card for: 見開く
# Creating card for: 剥がす
# Creating card for: 振るう
# Creating card for: 押し開く
# Creating card for: かじ取り
# Creating card for: 面食らう
# Creating card for: 思いの外
# Creating card for: 向こう側
# Creating card for: こちら側
# Creating card for: 目覚まし
# Creating card for: 押し出す
# Creating card for: 辿り着く
# Creating card for: そう伝聞
# Creating card for: 駆け寄る
# Creating card for: ････
# Creating card for: 取り残す
# Creating card for: 人となり
# Creating card for: 初々しい
# Creating card for: 小間使い
# Creating card for: 素知らぬ
# Creating card for: 問いかけ
# Creating card for: 耳慣れる
# Creating card for: 差し出す
# Creating card for: 聞き返す
# Creating card for: 立ち読み
# Creating card for: 聞き取る
# Creating card for: 歯ぎしり
# Creating card for: 相応しい
# Creating card for: 申しわけ
# Creating card for: 食い入る
# Creating card for: 思い切る
# Creating card for: 突っ伏す
# Creating card for: 出で立ち
# Creating card for: むき出し
# Creating card for: 締め直す
# Creating card for: 引き渡す
# Creating card for: 腰掛ける
# Creating card for: 飛び込む
# Creating card for: 貸し切る
# Creating card for: 話し合い
# Creating card for: 乗り切る
# Creating card for: 言葉遣い
# Creating card for: 有り難い
# Creating card for: 見透かす
# Creating card for: 消し飛ぶ
# Creating card for: 付き添う
# Creating card for: 赤茶ける
# Creating card for: 有り難う
# Creating card for: 突き出す
# Creating card for: 見付かる
# Creating card for: 受け取り
# Creating card for: 突き返す
# Creating card for: 請け負う
# Creating card for: 置き去り
# Creating card for: 然う然う
# Creating card for: 走り去る
# Creating card for: 清々しい
# Creating card for: 言い切る
# Creating card for: 押し込む
# Creating card for: 持ち帰る
# Creating card for: 冷やかし
# Creating card for: 今しがた
# Creating card for: 入り込む
# Creating card for: 仕方無い
# Creating card for: 頷き合う
# Creating card for: 覗き込む
# Creating card for: 吹き抜け
# Creating card for: 抱き付く
# Creating card for: そう様態
# Creating card for: 見据える
# Creating card for: 張り出す
# Creating card for: 手掛ける
# Creating card for: なり断定
# Creating card for: 見付ける
# Creating card for: 変わり者
# Creating card for: 起き上がる
# Creating card for: 吹き上げる
# Creating card for: 話し掛ける
# Creating card for: 思いっきり
# Creating card for: 執り行なう
# Creating card for: 取り掛かる
# Creating card for: 舞い上がる
# Creating card for: 叩きのめす
# Creating card for: 憎たらしい
# Creating card for: 差し掛かる
# Creating card for: 立ち込める
# Creating card for: だらし無い
# Creating card for: 突き付ける
# Creating card for: 問い掛ける
# Creating card for: 踏み付ける
# Creating card for: 転げ落ちる
# Creating card for: 待ちぼうけ
# Creating card for: 呼び掛ける
# Creating card for: 締めくくり
# Creating card for: 立ち上げる
# Creating card for: 込み上げる
# Creating card for: 突っ撥ねる
# Creating card for: 敷き詰める
# Creating card for: 落ちこぼれ
# Creating card for: 混ざり合う
# Creating card for: 撥ね除ける
# Creating card for: 入れ替わる
# Creating card for: 吊り下がる
# Creating card for: 田舎暮らし
# Creating card for: 突き詰める
# Creating card for: 打ち明ける
# Creating card for: 突き当たり
# Creating card for: 消え失せる
# Creating card for: 書き下ろし
# Creating card for: 蹴り飛ばす
# Creating card for: 世迷いごと
# Creating card for: 打っ飛ばす
# Creating card for: 染め上げる
# Creating card for: 浮かび上がる
# Creating card for: ･･････
# Create notes results:  0 55
# 6656 deck:nhg::3vocab Word:予 OR Word:伸 OR Word:称 OR Word:刷 OR Word:是 OR Word:= OR Word:読 OR Word:€ OR Word:負 OR Word:語 OR Word:徹 OR Word:◆ OR Word:立 OR Word:異 OR Word:☑ OR Word:助 OR Word:回 OR Word:当 OR Word:后 OR Word:観 OR Word:臨 OR Word:+ OR Word:･ OR Word:◇ OR Word:吹 OR Word:装 OR Word:〜 OR Word:© OR Word:再 OR Word:問 OR Word:嬢 OR Word:× OR Word:片 OR Word:素 OR Word:近 OR Word:室 OR Word:書 OR Word:館 OR Word:屋 OR Word:座 OR Word:聖 OR Word:栄 OR Word:童 OR Word:· OR Word:礫 OR Word:誉 OR Word:秀 OR Word:第 OR Word:腐 OR Word:超 OR Word:識 OR Word:% OR Word:師 OR Word:判 OR Word:官 OR Word:礼 OR Word:感 OR Word:― OR Word:優 OR Word:我 OR Word:丁 OR Word:延 OR Word:詬 OR Word:最 OR Word:頃 OR Word:Ő OR Word:譲 OR Word:貸 OR Word:隷 OR Word:職 OR Word:୪ OR Word:関 OR Word:肢 OR Word:定 OR Word:☐ OR Word:← OR Word:ㄖ OR Word:峰 OR Word:未 OR Word:少 OR Word:起 OR Word:代 OR Word:傍 OR Word:陣 OR Word:側 OR Word:全 OR Word:化 OR Word:並 OR Word:同 OR Word:✓ OR Word:業火 OR Word:悪鬼 OR Word:金貨 OR Word:転機 OR Word:素質 OR Word:ラ王 OR Word:要求 OR Word:一定 OR Word:契機 OR Word:造詣 OR Word:転送 OR Word:筋力 OR Word:製本 OR Word:近々 OR Word:不毛 OR Word:北端 OR Word:過労 OR Word:軍部 OR Word:実地 OR Word:火種 OR Word:随一 OR Word:ㄈㄨ OR Word:商業 OR Word:家臣 OR Word:真っ OR Word:無い OR Word:意地 OR Word:新規 OR Word:旨い OR Word:十全 OR Word:合本 OR Word:全土 OR Word:教導 OR Word:見目 OR Word:感服 OR Word:暗転 OR Word:権謀 OR Word:執務 OR Word:調達 OR Word:嫌み OR Word:過ぎ OR Word:売国 OR Word:呻く OR Word:奇異 OR Word:裁定 OR Word:山脈 OR Word:広々 OR Word:体質 OR Word:何に OR Word:自適 OR Word:奮起 OR Word:来訪 OR Word:半ば OR Word:造り OR Word:五十 OR Word:遠目 OR Word:賢君 OR Word:政争 OR Word:中庭 OR Word:生来 OR Word:真似 OR Word:占領 OR Word:聖堂 OR Word:鳥羽 OR Word:建国 OR Word:熟す OR Word:資質 OR Word:索敵 OR Word:喉元 OR Word:開放 OR Word:言及 OR Word:高々 OR Word:仰る OR Word:個室 OR Word:体裁 OR Word:薬草 OR Word:詰み OR Word:強気 OR Word:他所 OR Word:否々 OR Word:暴走 OR Word:鼻息 OR Word:主君 OR Word:轟音 OR Word:交易 OR Word:反る OR Word:望み OR Word:通路 OR Word:一心 OR Word:次期 OR Word:結界 OR Word:立身 OR Word:居る OR Word:後頭 OR Word:吐息 OR Word:歴代 OR Word:交差 OR Word:醜悪 OR Word:書類 OR Word:重用 OR Word:底辺 OR Word:祝勝 OR Word:持ち OR Word:適性 OR Word:旨味 OR Word:佐野 OR Word:一流 OR Word:数段 OR Word:爆裂 OR Word:因る OR Word:国体 OR Word:纏う OR Word:分断 OR Word:当分 OR Word:特に OR Word:大一 OR Word:五千 OR Word:有る OR Word:文面 OR Word:気質 OR Word:接近 OR Word:不敬 OR Word:商家 OR Word:常々 OR Word:宝玉 OR Word:一層 OR Word:称号 OR Word:書簡 OR Word:靡く OR Word:直撃 OR Word:益体 OR Word:弱小 OR Word:来客 OR Word:盛ん OR Word:一室 OR Word:転身 OR Word:雪景 OR Word:数十 OR Word:静脈 OR Word:運び OR Word:視界 OR Word:開花 OR Word:君主 OR Word:人目 OR Word:東方 OR Word:等分 OR Word:起動 OR Word:声音 OR Word:訪れ OR Word:自失 OR Word:喧騒 OR Word:賢者 OR Word:破竹 OR Word:内政 OR Word:駐留 OR Word:有無 OR Word:苦言 OR Word:十分 OR Word:穿つ OR Word:跳び OR Word:水晶 OR Word:動脈 OR Word:酔狂 OR Word:勇者 OR Word:羊皮 OR Word:強固 OR Word:決別 OR Word:最北 OR Word:黒い OR Word:実体 OR Word:格上 OR Word:大使 OR Word:病状 OR Word:黒髪 OR Word:軽々 OR Word:才気 OR Word:敬礼 OR Word:暴発 OR Word:親父 OR Word:容体 OR Word:沈痛 OR Word:質感 OR Word:魔導 OR Word:名目 OR Word:報せ OR Word:本国 OR Word:筆頭 OR Word:解体 OR Word:何故 OR Word:駐在 OR Word:詫び OR Word:政務 OR Word:口数 OR Word:上程 OR Word:肉食 OR Word:災厄 OR Word:先端 OR Word:勘気 OR Word:間近 OR Word:両輪 OR Word:深々 OR Word:久々 OR Word:强乱 OR Word:傾倒 OR Word:優等 OR Word:堪る OR Word:次代 OR Word:侵攻 OR Word:密偵 OR Word:達人 OR Word:装飾 OR Word:亜人 OR Word:六百 OR Word:人外 OR Word:品位 OR Word:易々 OR Word:主従 OR Word:風花 OR Word:魔物 OR Word:集う OR Word:旅人 OR Word:驚異 OR Word:素直 OR Word:要人 OR Word:為る OR Word:遣る OR Word:武官 OR Word:霊薬 OR Word:余る OR Word:回廊 OR Word:手配 OR Word:諸島 OR Word:納品 OR Word:二十 OR Word:番う OR Word:粗野 OR Word:停滞 OR Word:脱退 OR Word:脱力 OR Word:名君 OR Word:弱め OR Word:濃紺 OR Word:文官 OR Word:国政 OR Word:満喫 OR Word:右上 OR Word:小川 OR Word:貧国 OR Word:苦い OR Word:向き OR Word:大国 OR Word:付与 OR Word:一角 OR Word:摂政 OR Word:逃す OR Word:洗練 OR Word:目下 OR Word:仁徳 OR Word:支え OR Word:術数 OR Word:嘆き OR Word:鼻面 OR Word:突く OR Word:流石 OR Word:豪商 OR Word:恵み OR Word:意気 OR Word:対処 OR Word:襟元 OR Word:滾つ OR Word:特等 OR Word:落ち OR Word:背骨 OR Word:口調 OR Word:鉄板 OR Word:魔力 OR Word:立地 OR Word:大物 OR Word:決戦 OR Word:一気 O ...
# Cards found:  526
# ===== Start at: 2024-12-11 23:09:09.263965
# 526
# 526
# ===== Finished getting cards: 2024-12-11 23:09:11.593335
# Cards to schedule: 0
# Skipped due to key: 0
# Skipped else: 526
# ===== Now scheduling cards: 2024-12-11 23:09:11.593335
# ===== Finished scheduling cards: 2024-12-11 23:09:13.656052
# CPU times: total: 109 ms
# Wall time: 9.34 s
# (datetime.date(2024, 12, 12), 0, 526)

# %%
SKIP_DECK = "nhg::3vocab::unneeded"

def auto_add_and_set(word, ivl, force_schedule=False, skip_schedule=False, wait_for_type=True):
    """
    Create and set schedule of a card.

    Args:
        word: word
        ivl: interval to set for known word
        force_schedule: If true, sets due date to interval even if it's already learned
        skip_schedule: Do not schedule, only create the card
        wait_for_type: wait for card to be fully created or skip it

    Returns:
        return code
        -3 key type doesn't exist yet
        -2 "Error"
        -1 "Not Found", 
        0 date given (success)
        1 skipping
        2 skipping scheduling - alr in deck
        3 skipping scheduling - in unneeded
    """
    print("--START-- auto_add_and_set -- ", word)
    if not word:
        return 1
    
    card_id = get_word_card_id(word)
    if not card_id:
        card_id = create_note(word)
    if card_id in {-2}:
        return -2
    elif card_id in {-1}:
        return -1
    elif card_id in {0}:
        return 2
        
    print(card_id)
    if skip_schedule:
        return 1
    # check_card_unlearned
    if not force_schedule:
        while True:
            try: 
                card_info = invoke("cardsInfo", cards=[card_id])
                if card_info[0]["deckName"] == SKIP_DECK:
                    print("Skipping scheduling. Not needed")
                    return 3
                if card_info[0]["type"] or card_info[0]["queue"]:
                    print("Skipping scheduling. Not a new card")
                    print("Card Interval:", card_info[0]["interval"])
                    return 2
            except KeyError as e:
                # This just doesn't work on retry. Maybe due to some lock?
                print(f"Key 'type' doesn't exist yet. Skipping.")
                return 1
            break

    result = set_card_learned(card_id, ivl)
    if result:
        return 0
    else:
        return -2

# %%
# -1: <3s
# 0: 6-15s -> maybe avg 8.4 seconds?
# 0: key type reschedule 6-7s
# 1: 6-7s
# 2: ~4.1s
auto_add_and_set("見識", 21, skip_schedule=False)
# Out:
# --START-- auto_add_and_set --  見識
# Finding card id for: 見識
# 1733812573831
# Skipping scheduling. Not a new card
# Card Interval: 21
# 2

# %%
def batch_add(words, ivl=-1, skip_schedule=True, force_schedule=True):
    words_result_map = dict()
    for i in range(len(words)):
        print(i)
        word = words[i]
        try:
            result = auto_add_and_set(
                word, 
                ivl, 
                skip_schedule=skip_schedule,
                force_schedule=force_schedule,
            )
            words_result_map[word] = result
        except Exception as e:
            print(e)
            words_result_map[word] = -1
        finally:
            print(f"{word}: {words_result_map[word]}")
            print()
    return words_result_map

# %%
FILE_NAME = "parsed/metaphor.txt"
easy, low = analyze_list(FILE_NAME)
# Out:
# --
# To learn:	 22 {'焚', '凱', '骸', '播', '叙', '醐', '譚', '斡', '猶', '冑', '鞍', '芳', '醇', '牽', '拙', '傑', '魁', '駿', '猊', '嗅', '燻', '醍'}
# Learned:	 198 {'袋', '造', '人', '二', '暮', '隊', '率', '信', '口', '細', '声', '製', '気', '為', '店', '辻', '野', '国', '差', '咎', '賞', '約', '息', '郷', '濡', '露', '欺', '碑', '英', '生', '婦', '管', '服', '衣', '馬', '廷', '乱', '末', '石', '闘', '敬', '覇', '聞', '境', '標', '明', '血', '替', '砂', '伝', '抵', '件', '切', '的', '底', '民', '鳥', '荒', '目', '干', '働', '商', '並', '祈', '怪', '地', '練', '具', '兵', '産', '状', '理', '威', '介', '撃', '賢', '勲', '香', '体', '火', '根', '立', '上', '首', '制', '先', '叫', '愚', '迫', '配', '導', '小', '光', '名', '突', '子', '霊', '破', '勢', '憎', '鼓', '防', '条', '弄', '改', '輩', '硝', '亡', '神', '砲', '対', '統', '仲', '度', '夕', '領', '師', '湖', '塊', '装', '作', '肉', '者', '売', '辺', '皆', '手', '締', '臭', '安', '想', '静', '格', '命', '逃', '位', '宮', '評', '返', '心', '旋', '八', '寝', '蓄', '引', '品', '出', '面', '架', '償', '峰', '下', '矢', '肝', '雄', '銘', '価', '草', '百', '金', '路', '物', '辛', '覚', '害', '書', '外', '公', '長', '番', '板', '城', '健', '味', '元', '予', '見', '政', '這', '示', '世', '無', '舞', '得', '刻', '別', '空', '門', '戸', '際', '憂', '備', '器', '大', '技', '甲', '粋', '主'}
# Not Found:	 5 {'褄', '蟲', '扈', '*', '跋'}
# --
# to learn:	 39 {'償う', '覇者', '技師', '荒野', '架空', '品評', '破格', '野心', '統率', 'いざこざ', '皆目', '先導', '焚火', '信条', '公示', '鼓舞', '備蓄', '地位', '斡旋', '標的', '亡骸', '甲板', '砲撃', '心細い', '口外', '装甲', '夕刻', '袋小路', '商い', '見聞', '露店', '婦人', '仲介', '傑作', '差出人', 'とんだ', '迫害', '公約', '辺境'}
# learned:	 12 {'産地', '野暮', '手練', '乱立', '辻褄', '賢明', '対価', '猶予', '宮廷', '英気', '民', '英雄譚'}
# to add:	 89 {'', '矢面', '売名', '末路', '神器', '元首', '防具', '欺ける', '並大抵', '手配書', 'はらわた', '這いずる', '肉塊', '地底湖', '寝静まる', '練度', '香草', '健闘を祈る', '管状', '別働隊', '得体', '金品', '粋がる', '跋扈', '燻製', '根城', '醍醐味', 'がんじがらめ', '蟲', '肝に銘じる', '元締め', 'ひときわ', '空位', '濡れ衣', '咎人', '硝子', '凱旋', '勢いづく', '嗅覚', '駿馬', '愚弄', '芳醇', '逃亡者', '門戸', 'いわくつき', '賞金首', '八百長', '**下命**', '無二', '領主', '輩', '牽制', '叙勲', '血なまぐさい', '敬服', '番兵', '理想郷', '拙者', '伝声管', '件の', '突っ返す', '公国', 'たかが', '砂地', '猊下', '生憎', 'さながら', 'なすすべもない', '伝播', '霊峰', '干上がる', '物憂げ', 'さらう', '安息', '名だたる', '石碑', '引き際', '威光', '鞍替え', '雄叫び', '**改造**', '見世物', '甲冑', '辛気臭い', '首魁', '怪鳥', 'ほぐれる', '為政者', '見切る'}
# to skip:	 0 set()
# failed:	 0 []
# --
# wf_kt,	Easy Words: 110 ['', '蟲', '輩', '矢面', '売名', '末路', '神器', '荒野', '元首', '品評', '防具', '破格', '野心', '統率', '皆目', '信条', '公示', '肉塊', '標的', '練度', '香草', '管状', '見聞', '得体', '金品', '跋扈', '根城', '辺境', '覇者', '空位', '咎人', '硝子', '愚弄', '門戸', '装甲', '露店', '婦人', '無二', '仲介', '公約', '商い', '領主', '先導', '敬服', '鼓舞', '番兵', '地位', '甲板', '口外', '件の', '公国', '夕刻', '砂地', '生憎', '償う', '技師', '架空', '霊峰', '安息', '備蓄', '石碑', '威光', '砲撃', '怪鳥', '迫害', '欺ける', '並大抵', '手配書', '地底湖', '別働隊', '粋がる', '差出人', 'とんだ', '元締め', '濡れ衣', '逃亡者', '心細い', '賞金首', '八百長', '理想郷', '伝声管', '袋小路', 'たかが', '物憂げ', 'さらう', '引き際', '雄叫び', '見世物', '為政者', '見切る', 'はらわた', '這いずる', '寝静まる', 'ひときわ', '勢いづく', 'いざこざ', '突っ返す', 'さながら', '干上がる', '名だたる', '辛気臭い', 'ほぐれる', '健闘を祈る', '肝に銘じる', 'いわくつき', 'がんじがらめ', '**下命**', '血なまぐさい', '**改造**', 'なすすべもない']
# wf_kf,	Low Prio Word: 18 {'拙者', '駿馬', '芳醇', '焚火', '叙勲', '猊下', '鞍替え', '亡骸', '甲冑', '伝播', '凱旋', '首魁', '傑作', '牽制', '燻製', '嗅覚', '醍醐味', '斡旋'}
# wt_kf,	High Prio Kanji: 2 {'英雄譚', '猶予'}
# wt_kt,	Known Words: 10 ['民', '産地', '野暮', '手練', '乱立', '辻褄', '賢明', '対価', '宮廷', '英気']
# UNNEEDED (SKIP): 	 0 []

# %%
# %%time
# %%capture cap

ivl=7
results = batch_add(
    easy+low, 
    ivl=ivl, 
    skip_schedule=False, 
    force_schedule=False,
)



# -> save this to a file 
results
len(results)
# results_sorted = {y: x for x, y in results.items()}
inv_map = {}
for k, v in results.items():
    inv_map[v] = inv_map.get(v, []) + [k]

total = 0
for k, values in inv_map.items():
    total += len(values)
print(total)

RESULTS_PATH = "parsed"
RESULTS_FILE = "results.json"
with open(os.path.join(RESULTS_PATH, RESULTS_FILE), "w", encoding="utf-8") as json_file:
    json.dump(inv_map, json_file, indent=4, ensure_ascii=False)
# Out:
# CPU times: total: 422 ms
# Wall time: 12min 20s

# %% [markdown]
# 128 words with skip schedule (with 76 created):
# - CPU times: total: 344 ms
# - Wall time: 7min 13s
# -> avg 3.38s per card
#
# on same 128 cards -> schedule:
# - CPU times: total: 422 ms
# - Wall time: 12min 20s
# -> avg 5.78s per card
#
#
# DO NOT CAPTURE BUT LOG PROGRESS INSTEAD OF EACH INDIVIDUAL ONE
# (by percentage)
#
#
# Scheduling is the bottleneck. Would it be fine to have concurrent adds / edits to different cards?
#     https://github.com/FooSoft/anki-connect/issues/2

# %% [markdown]
# # final step:
# debug / confirm:
# - words that didn't get added
# - weird words that were added
# - overlappping words effort (not duplicates, but extremely similar to another word)
#
# optimize:
# - card creation api (jisho)
# - card creation itself
# - scheduling: would it be faster to separate scheduling and card creation? for parallelizing
#     - would it be ok to parallelize on the db for separate entries?

# %% [markdown]
# # finishing touches:
# - create a repo for this -> on unit_test? should unit_test be our public github?
# - FREE version will be Tesseract OCR only (paid is GCP + Tesseract)
# - convert this ipynb to a script, with all the sub tools
# - clean up dirs and make things usable (from perspective of a clueless user)
# - super over engineered version (prioritized):
#     - Create a setup guide
#     - code review everything first
#     - publish this to github - put a disclaimer saying it's very general
#         - disable issues, comments, etc
#     - QT or pillow screenshot area selector
#     - polling version of the pipeline (screenshot by screenshot)
#         - use separate clipboard than OS clipboard
#     - parallelize all parts of the pipeline
#         screenshots,
#     - web frontend (offline)
#     - refactor for unit and integration testing
#
#     - generalize all parts of the pipeline for different types of users
#         - ocr engine
#         - dictionary
#         - anki decks
#         - anki note type
#     - make a frontend / backend and host parts of this
#         - make a hub personal website to host ALL my personal projects
#         - load balancer to keep people out
#         - login with google only
#     - make a desktop version
